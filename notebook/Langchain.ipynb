# %%
import os

import json
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from typing import Optional, List
import datetime
from langchain_core.pydantic_v1 import BaseModel, Field
from serpapi import GoogleSearch

from dotenv import load_dotenv

_ = load_dotenv()

# %% [markdown]
# ## 1. Initialize objects

# %%
llm = ChatOpenAI(model="gpt-4o")

# %% [markdown]
# ## 2. Creation travel plan

# %%
GPTRAVEL_PROMPT_TRAVEL_PLAN_TEMPLATE = """
You are an intelligent travel planner.

The user is interested to travel to {destination} between {departure_date} and {return_date}. 
In addition to that the user suggested this for his/her travel: "{travel_text}".
With this in mind, generate a JSON that could contain a travel plan that could match user interests.
In the travel plan, please avoid activties related to flights and transports, also everything included about the accomodation and the restaurants. 
Just tell what to do when the user is at destination.
"""

class Activity(BaseModel):
    """Activity"""
    time: datetime.datetime = Field(description='Approximate time of the activicty. The format should be YYYY-MM-DD HH:MM:SS')
    place: str              = Field(description='Name of the place where is located the activicty')
    description: str        = Field(description='Description of the activicty')

class DayPlan(BaseModel):
    """Plan of a day in the travel plan"""
    date: datetime.date          = Field(description="Date of the plan.")
    activities: List[Activity]   = Field(description="List of activities to do in the day plan.")

class TravelPlan(BaseModel):
    """Travel plan"""
    
    day_plans: List[DayPlan] = Field(description="List of day plans activities.")

print(GPTRAVEL_PROMPT_TRAVEL_PLAN_TEMPLATE)
# Out:
# You are an intelligent travel planner.
#
# The user is interested to travel to {destination} between {departure_date} and {return_date}.
# In addition to that the user suggested this for his/her travel: "{travel_text}".
# With this in mind, generate a JSON that could contain a travel plan that could match user interests.
# In the travel plan, please avoid activties related to flights and transports, also everything included about the accomodation and the restaurants.
# Just tell what to do when the user is at destination.

# %%
prompt_template = PromptTemplate(
    input_variables=["destination", "departure_date", "return_date", "travel_text"],
    template=GPTRAVEL_PROMPT_TRAVEL_PLAN_TEMPLATE
)


structured_llm = llm.with_structured_output(TravelPlan)

# %%
user_input = {
    "destination": "Paris",
    "departure_date": "2024-10-31",
    "return_date": "2024-11-02",
    "travel_text": "I wanna visit Paris with my girlfriend in a romantic weekend. I'd love to impress her but at the same time I'd love to visit the best places of the city. I would like to sleep also in a good place, maximum 300 euros per night."
}

user_input
# Out:
# {'destination': 'Paris',
#  'departure_date': '2024-10-31',
#  'return_date': '2024-11-02',
#  'travel_text': "I wanna visit Paris with my girlfriend in a romantic weekend. I'd love to impress her but at the same time I'd love to visit the best places of the city. I would like to sleep also in a good place, maximum 300 euros per night."}

# %%
print(
    prompt_template.format(
        **user_input
    )
)
# Out:
# You are an intelligent travel planner.
#
# The user is interested to travel to Paris between 2024-10-31 and 2024-11-02.
# In addition to that the user suggested this for his/her travel: "I wanna visit Paris with my girlfriend in a romantic weekend. I'd love to impress her but at the same time I'd love to visit the best places of the city. I would like to sleep also in a good place, maximum 300 euros per night.".
# With this in mind, generate a JSON that could contain a travel plan that could match user interests.
# In the travel plan, please avoid activties related to flights and transports, also everything included about the accomodation and the restaurants.
# Just tell what to do when the user is at destination.

# %%
travel_plan_output = structured_llm.invoke(
    prompt_template.format(**user_input)
)

# %%
print(travel_plan_output.json())
# Out:
# {"day_plans": [{"date": "2024-10-31", "activities": [{"time": "2024-10-31T10:00:00", "place": "Eiffel Tower", "description": "Start your romantic weekend with a visit to the iconic Eiffel Tower. Take an elevator ride to the top for a breathtaking view of Paris."}, {"time": "2024-10-31T12:00:00", "place": "Champs-\u00c9lys\u00e9es", "description": "Stroll down the famous avenue, stopping by luxury boutiques and cafes. Enjoy some shopping and people-watching."}, {"time": "2024-10-31T15:00:00", "place": "Louvre Museum", "description": "Visit the world's largest art museum and a historic monument in Paris. Don't miss the Mona Lisa and the Venus de Milo."}, {"time": "2024-10-31T18:00:00", "place": "Seine River", "description": "Take a romantic evening cruise on the Seine River. Enjoy the beautiful views of the city's landmarks illuminated at night."}]}, {"date": "2024-11-01", "activities": [{"time": "2024-11-01T10:00:00", "place": "Montmartre", "description": "Explore the charming district of Montmartre. Visit the Basilica of the Sacr\u00e9-C\u0153ur and enjoy the artistic atmosphere."}, {"time": "2024-11-01T12:00:00", "place": "Le Marais", "description": "Wander through the historic Le Marais district. Discover its narrow streets, trendy boutiques, and historic buildings."}, {"time": "2024-11-01T15:00:00", "place": "Notre-Dame Cathedral", "description": "Visit the stunning Notre-Dame Cathedral. Admire its Gothic architecture and explore its interior."}, {"time": "2024-11-01T18:00:00", "place": "Luxembourg Gardens", "description": "Take a romantic walk in the beautiful Luxembourg Gardens. Relax by the fountains and enjoy the serene environment."}]}, {"date": "2024-11-02", "activities": [{"time": "2024-11-02T10:00:00", "place": "Mus\u00e9e d'Orsay", "description": "Visit the Mus\u00e9e d'Orsay, known for its impressive collection of Impressionist and Post-Impressionist masterpieces."}, {"time": "2024-11-02T12:00:00", "place": "Saint-Germain-des-Pr\u00e9s", "description": "Explore the historic Saint-Germain-des-Pr\u00e9s neighborhood. Visit its famous cafes and bookstores."}, {"time": "2024-11-02T15:00:00", "place": "Palace of Versailles", "description": "Take a half-day trip to the Palace of Versailles. Explore the opulent palace and its stunning gardens."}, {"time": "2024-11-02T18:00:00", "place": "Montparnasse Tower", "description": "End your romantic weekend with a visit to the Montparnasse Tower. Enjoy a panoramic view of Paris at sunset."}]}]}

# %% [markdown]
# ## 3a. From travel plan to check flights

# %%
GPTRAVEL_PROMPT_FLIGHT_QUERY_TEMPLATE = """
You are an intelligent travel planner.

The user is departing from {departure} and he plans to go to {destination}. 
You have previously generated the following travel plan: {travel_plan}

Given this in mind, we need to get the information required for calling SerpAPI for the search flights. 
Important: the dates of travel should be the first day of the travel plan for the outbound flight and the last day of the travel plan for the return flight.
You must give in output two inputs for the API, one for the outbound flight and the other for the return flight.
"""

DEPARTURE_ID_DESCRIPTION = """Parameter defines the departure airport code or location kgmid.
An airport code is an uppercase 3-letter code. You can search for it on Google Flights or IATA.
For example, CDG is Paris Charles de Gaulle Airport and AUS is Austin-Bergstrom International Airport.
A location kgmid is a string that starts with /m/. You can search for a location on Wikidata and use its "Freebase ID" as the location kgmid. For example, /m/0vzm is the location kgmid for Austin, TX.
You can specify multiple departure airports by separating them with a comma. For example, CDG,ORY,/m/04jpl
"""

ARRIVAL_ID_DESCRIPTION = """Parameter defines the arrival airport code or location kgmid.
An airport code is an uppercase 3-letter code. You can search for it on Google Flights or IATA.
For example, CDG is Paris Charles de Gaulle Airport and AUS is Austin-Bergstrom International Airport.
A location kgmid is a string that starts with /m/. You can search for a location on Wikidata and use its "Freebase ID" as the location kgmid. For example, /m/0vzm is the location kgmid for Austin, TX.
You can specify multiple arrival airports by separating them with a comma. For example, CDG,ORY,/m/04jpl
"""


class FlightSearchParameters(BaseModel):
    """Flight Search parameters"""

    departure_id: str = Field(description=DEPARTURE_ID_DESCRIPTION)
    arrival_id: str   = Field(description=ARRIVAL_ID_DESCRIPTION)

    date: datetime.date = Field(description="Date of the flight")


class SearchInputs(BaseModel):
    """Search Inputs for Travel"""
    outbound_input: FlightSearchParameters = Field(description='flight search parameters for the outbound flight')
    return_input: FlightSearchParameters   = Field(description='flight search parameters for the return flight')



print(GPTRAVEL_PROMPT_FLIGHT_QUERY_TEMPLATE)
# Out:
# You are an intelligent travel planner.
#
# The user is departing from {departure} and he plans to go to {destination}.
# You have previously generated the following travel plan: {travel_plan}
#
# Given this in mind, we need to get the information required for calling SerpAPI for the search flights.
# Important: the dates of travel should be the first day of the travel plan for the outbound flight and the last day of the travel plan for the return flight.
# You must give in output two inputs for the API, one for the outbound flight and the other for the return flight.

# %%
llm_search_flight = ChatOpenAI(model="gpt-4o")


prompt_template_search_flights = PromptTemplate(
    input_variables=["departure", "destination", "travel_plan"],
    template=GPTRAVEL_PROMPT_FLIGHT_QUERY_TEMPLATE
)


structured_llm_search_flights = llm_search_flight.with_structured_output(SearchInputs)

# %%
params_search_flight = {
    "departure": "Milan",
    "destination": "Paris",
    "travel_plan": travel_plan_output.json()
}

print(prompt_template_search_flights.format(**params_search_flight))
# Out:
# You are an intelligent travel planner.
#
# The user is departing from Milan and he plans to go to Paris.
# You have previously generated the following travel plan: {"day_plans": [{"date": "2024-10-31", "activities": [{"time": "2024-10-31T10:00:00", "place": "Eiffel Tower", "description": "Start your romantic weekend with a visit to the iconic Eiffel Tower. Take an elevator ride to the top for a breathtaking view of Paris."}, {"time": "2024-10-31T12:00:00", "place": "Champs-\u00c9lys\u00e9es", "description": "Stroll down the famous avenue, stopping by luxury boutiques and cafes. Enjoy some shopping and people-watching."}, {"time": "2024-10-31T15:00:00", "place": "Louvre Museum", "description": "Visit the world's largest art museum and a historic monument in Paris. Don't miss the Mona Lisa and the Venus de Milo."}, {"time": "2024-10-31T18:00:00", "place": "Seine River", "description": "Take a romantic evening cruise on the Seine River. Enjoy the beautiful views of the city's landmarks illuminated at night."}]}, {"date": "2024-11-01", "activities": [{"time": "2024-11-01T10:00:00", "place": "Montmartre", "description": "Explore the charming district of Montmartre. Visit the Basilica of the Sacr\u00e9-C\u0153ur and enjoy the artistic atmosphere."}, {"time": "2024-11-01T12:00:00", "place": "Le Marais", "description": "Wander through the historic Le Marais district. Discover its narrow streets, trendy boutiques, and historic buildings."}, {"time": "2024-11-01T15:00:00", "place": "Notre-Dame Cathedral", "description": "Visit the stunning Notre-Dame Cathedral. Admire its Gothic architecture and explore its interior."}, {"time": "2024-11-01T18:00:00", "place": "Luxembourg Gardens", "description": "Take a romantic walk in the beautiful Luxembourg Gardens. Relax by the fountains and enjoy the serene environment."}]}, {"date": "2024-11-02", "activities": [{"time": "2024-11-02T10:00:00", "place": "Mus\u00e9e d'Orsay", "description": "Visit the Mus\u00e9e d'Orsay, known for its impressive collection of Impressionist and Post-Impressionist masterpieces."}, {"time": "2024-11-02T12:00:00", "place": "Saint-Germain-des-Pr\u00e9s", "description": "Explore the historic Saint-Germain-des-Pr\u00e9s neighborhood. Visit its famous cafes and bookstores."}, {"time": "2024-11-02T15:00:00", "place": "Palace of Versailles", "description": "Take a half-day trip to the Palace of Versailles. Explore the opulent palace and its stunning gardens."}, {"time": "2024-11-02T18:00:00", "place": "Montparnasse Tower", "description": "End your romantic weekend with a visit to the Montparnasse Tower. Enjoy a panoramic view of Paris at sunset."}]}]}
#
# Given this in mind, we need to get the information required for calling SerpAPI for the search flights.
# Important: the dates of travel should be the first day of the travel plan for the outbound flight and the last day of the travel plan for the return flight.
# You must give in output two inputs for the API, one for the outbound flight and the other for the return flight.

# %%
search_flights_input_query_output = structured_llm_search_flights.invoke(
    prompt_template_search_flights.format(**params_search_flight)
)

# %%
search_flighhts_inputs = json.loads(search_flights_input_query_output.json())

search_flighhts_inputs
# Out:
# {'outbound_input': {'departure_id': 'MXP',
#   'arrival_id': 'CDG',
#   'date': '2024-10-31'},
#  'return_input': {'departure_id': 'CDG',
#   'arrival_id': 'MXP',
#   'date': '2024-11-02'}}

# %%
search_flight_result = {}

for flight_name, search_flighhts_input in search_flighhts_inputs.items():
    
    params = {
      "engine": "google_flights",
      "departure_id": search_flighhts_input['departure_id'],
      "arrival_id": search_flighhts_input['arrival_id'],
      "outbound_date": search_flighhts_input['date'],
      "currency": "EUR",
      "type": "2",
      "api_key": os.environ["SERPAPI_KEY"]
    }

    search = GoogleSearch(params)
    search_flight_result[flight_name] = search.get_dict()

# %%
search_flight_result['outbound_input']
# Out:
# {'search_metadata': {'id': '66d318d4d16915b8a69d66ee',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/bb6e505c312607ec/66d318d4d16915b8a69d66ee.json',
#   'created_at': '2024-08-31 13:21:24 UTC',
#   'processed_at': '2024-08-31 13:21:24 UTC',
#   'google_flights_url': 'https://www.google.com/travel/flights?hl=en&gl=us&curr=EUR&tfs=CBwQAhoeEgoyMDI0LTEwLTMxagcIARIDTVhQcgcIARIDQ0RHQgEBSAFwAZgBAg==',
#   'raw_html_file': 'https://serpapi.com/searches/bb6e505c312607ec/66d318d4d16915b8a69d66ee.html',
#   'prettify_html_file': 'https://serpapi.com/searches/bb6e505c312607ec/66d318d4d16915b8a69d66ee.prettify',
#   'total_time_taken': 1.27},
#  'search_parameters': {'engine': 'google_flights',
#   'hl': 'en',
#   'gl': 'us',
#   'type': '2',
#   'departure_id': 'MXP',
#   'arrival_id': 'CDG',
#   'outbound_date': '2024-10-31',
#   'currency': 'EUR'},
#  'best_flights': [{'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 15:45'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 17:15'},
#      'duration': 90,
#      'airplane': 'Airbus A319',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 3809',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 77 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 77000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 28},
#    'price': 118,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pWTWpNNE1Ea2FDZ2lYWEJBQ0dnTkZWVkk0SEhEN1pRPT0iLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIlUyIiwiMzgwOSJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 16:05'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 17:35'},
#      'duration': 90,
#      'airplane': 'Airbus A319',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1331',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Wi-Fi for a fee',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 83 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 83000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 38},
#    'price': 181,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pCUmpFek16RWFDd2puakFFUUFob0RSVlZTT0J4dzRKc0IiLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIkFGIiwiMTMzMSJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 12:35'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 14:05'},
#      'duration': 90,
#      'airplane': 'Airbus A320',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1131',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Wi-Fi for a fee',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 69 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 69000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 15},
#    'price': 190,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pCUmpFeE16RWFDd2pya3dFUUFob0RSVlZTT0J4d3hLTUIiLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIkFGIiwiMTEzMSJdXV0='}],
#  'other_flights': [{'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 19:05'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 20:40'},
#      'duration': 95,
#      'airplane': 'Airbus A320',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 3811',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 69 kg'],
#      'often_delayed_by_over_30_min': True}],
#    'total_duration': 95,
#    'carbon_emissions': {'this_flight': 69000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 15},
#    'price': 114,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pWTWpNNE1URWFDZ2pWV0JBQ0dnTkZWVkk0SEhDS1lnPT0iLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIlUyIiwiMzgxMSJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 06:25'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 08:00'},
#      'duration': 95,
#      'airplane': 'Airbus A320',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 3805',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 69 kg']}],
#    'total_duration': 95,
#    'carbon_emissions': {'this_flight': 69000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 15},
#    'price': 132,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pWTWpNNE1EVWFDZ2pkWmhBQ0dnTkZWVkk0SEhEUmNRPT0iLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIlUyIiwiMzgwNSJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 13:15'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 14:45'},
#      'duration': 90,
#      'airplane': 'Airbus A320',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 4544',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 69 kg'],
#      'often_delayed_by_over_30_min': True}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 69000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 15},
#    'price': 132,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pWTWpRMU5EUWFDZ2pkWmhBQ0dnTkZWVkk0SEhEUmNRPT0iLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIlUyIiwiNDU0NCJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 18:05'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 19:40'},
#      'duration': 95,
#      'airplane': 'Airbus A321',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 3813',
#      'legroom': '28 in',
#      'extensions': ['Below average legroom (28 in)',
#       'Carbon emissions estimate: 68 kg'],
#      'often_delayed_by_over_30_min': True}],
#    'total_duration': 95,
#    'carbon_emissions': {'this_flight': 68000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 13},
#    'price': 132,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pWTWpNNE1UTWFDZ2pkWmhBQ0dnTkZWVkk0SEhEUmNRPT0iLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIlUyIiwiMzgxMyJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 08:25'},
#      'arrival_airport': {'name': 'Luxembourg Airport',
#       'id': 'LUX',
#       'time': '2024-10-31 09:45'},
#      'duration': 80,
#      'airplane': 'De Havilland-Bombardier Dash-8',
#      'airline': 'Luxair',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LG.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LG 6992',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'Carbon emissions estimate: 43 kg']},
#     {'departure_airport': {'name': 'Luxembourg Airport',
#       'id': 'LUX',
#       'time': '2024-11-01 16:00'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-01 17:00'},
#      'duration': 60,
#      'airplane': 'De Havilland-Bombardier Dash-8',
#      'airline': 'Luxair',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LG.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LG 8019',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'Carbon emissions estimate: 31 kg']}],
#    'layovers': [{'duration': 1815,
#      'name': 'Luxembourg Airport',
#      'id': 'LUX',
#      'overnight': True}],
#    'total_duration': 1955,
#    'carbon_emissions': {'this_flight': 75000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 25},
#    'price': 140,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LG.png',
#    'extensions': ['Checked baggage not included in price',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': ''},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 11:50'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 13:20'},
#      'duration': 90,
#      'airplane': 'Airbus A320',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 3807',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 69 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 69000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 15},
#    'price': 154,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pWTWpNNE1EY2FDZ2luZUJBQ0dnTkZWVkk0SEhDS2hRRT0iLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIlUyIiwiMzgwNyJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 15:00'},
#      'arrival_airport': {'name': 'Zurich Airport',
#       'id': 'ZRH',
#       'time': '2024-10-31 16:00'},
#      'duration': 60,
#      'airplane': 'Embraer 190',
#      'airline': 'SWISS',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LX 1629',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 54 kg'],
#      'often_delayed_by_over_30_min': True},
#     {'departure_airport': {'name': 'Zurich Airport',
#       'id': 'ZRH',
#       'time': '2024-10-31 17:35'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 18:50'},
#      'duration': 75,
#      'airplane': 'Airbus A320',
#      'airline': 'SWISS',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LX 644',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 63 kg'],
#      'often_delayed_by_over_30_min': True}],
#    'layovers': [{'duration': 95, 'name': 'Zurich Airport', 'id': 'ZRH'}],
#    'total_duration': 230,
#    'carbon_emissions': {'this_flight': 118000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 97},
#    'price': 161,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': ''},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 18:40'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 20:15'},
#      'duration': 95,
#      'airplane': 'Airbus A220-300 Passenger',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1731',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'Wi-Fi for a fee',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 66 kg']}],
#    'total_duration': 95,
#    'carbon_emissions': {'this_flight': 67000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 12},
#    'price': 233,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pCUmpFM016RWFDd2kzdFFFUUFob0RSVlZTT0J4dzJNZ0IiLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIkFGIiwiMTczMSJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 19:10'},
#      'arrival_airport': {'name': 'Zurich Airport',
#       'id': 'ZRH',
#       'time': '2024-10-31 20:10'},
#      'duration': 60,
#      'airplane': 'Embraer 190',
#      'airline': 'SWISS',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LX 1623',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 54 kg'],
#      'often_delayed_by_over_30_min': True},
#     {'departure_airport': {'name': 'Zurich Airport',
#       'id': 'ZRH',
#       'time': '2024-10-31 20:55'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 22:15'},
#      'duration': 80,
#      'airplane': 'Embraer 195 E2',
#      'airline': 'SWISS',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LX 646',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 68 kg'],
#      'often_delayed_by_over_30_min': True}],
#    'layovers': [{'duration': 45, 'name': 'Zurich Airport', 'id': 'ZRH'}],
#    'total_duration': 185,
#    'carbon_emissions': {'this_flight': 123000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 105},
#    'price': 255,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': ''},
#   {'flights': [{'departure_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-10-31 11:35'},
#      'arrival_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-10-31 13:10'},
#      'duration': 95,
#      'airplane': 'Airbus A220-300 Passenger',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1831',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'Wi-Fi for a fee',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 66 kg']}],
#    'total_duration': 95,
#    'carbon_emissions': {'this_flight': 67000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 12},
#    'price': 274,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJUzBSR2IxSmZaazVxWDBWQlNtbEhNbWRDUnkwdExTMHRMUzB0TFhaM1luQXlORUZCUVVGQlIySlVSMDVWUW1KMlVuVkJFZ1pCUmpFNE16RWFDd2k3MVFFUUFob0RSVlZTT0J4d2ord0IiLFtbIk1YUCIsIjIwMjQtMTAtMzEiLCJDREciLG51bGwsIkFGIiwiMTgzMSJdXV0='}],
#  'price_insights': {'lowest_price': 114,
#   'price_level': 'high',
#   'typical_price_range': [20, 65],
#   'price_history': [[1719871200, 69],
#    [1719957600, 69],
#    [1720044000, 69],
#    [1720130400, 66],
#    [1720216800, 66],
#    [1720303200, 66],
#    [1720389600, 78],
#    [1720476000, 78],
#    [1720562400, 78],
#    [1720648800, 78],
#    [1720735200, 69],
#    [1720821600, 69],
#    [1720908000, 69],
#    [1720994400, 69],
#    [1721080800, 69],
#    [1721167200, 69],
#    [1721253600, 69],
#    [1721340000, 69],
#    [1721426400, 69],
#    [1721512800, 69],
#    [1721599200, 78],
#    [1721685600, 78],
#    [1721772000, 78],
#    [1721858400, 78],
#    [1721944800, 71],
#    [1722031200, 71],
#    [1722117600, 71],
#    [1722204000, 71],
#    [1722290400, 71],
#    [1722376800, 71],
#    [1722463200, 78],
#    [1722549600, 41],
#    [1722636000, 46],
#    [1722722400, 56],
#    [1722808800, 56],
#    [1722895200, 61],
#    [1722981600, 61],
#    [1723068000, 84],
#    [1723154400, 78],
#    [1723240800, 78],
#    [1723327200, 78],
#    [1723413600, 78],
#    [1723500000, 80],
#    [1723586400, 84],
#    [1723672800, 87],
#    [1723759200, 84],
#    [1723845600, 84],
#    [1723932000, 84],
#    [1724018400, 100],
#    [1724104800, 100],
#    [1724191200, 100],
#    [1724277600, 100],
#    [1724364000, 84],
#    [1724450400, 100],
#    [1724536800, 100],
#    [1724623200, 103],
#    [1724709600, 103],
#    [1724796000, 103],
#    [1724882400, 84],
#    [1724968800, 98],
#    [1725055200, 114]]}}

# %%
search_flight_result['return_input']
# Out:
# {'search_metadata': {'id': '66d318d61a5b54adb4316375',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/bb6e505c312607ec/66d318d61a5b54adb4316375.json',
#   'created_at': '2024-08-31 13:21:26 UTC',
#   'processed_at': '2024-08-31 13:21:26 UTC',
#   'google_flights_url': 'https://www.google.com/travel/flights?hl=en&gl=us&curr=EUR&tfs=CBwQAhoeEgoyMDI0LTExLTAyagcIARIDQ0RHcgcIARIDTVhQQgEBSAFwAZgBAg==',
#   'raw_html_file': 'https://serpapi.com/searches/bb6e505c312607ec/66d318d61a5b54adb4316375.html',
#   'prettify_html_file': 'https://serpapi.com/searches/bb6e505c312607ec/66d318d61a5b54adb4316375.prettify',
#   'total_time_taken': 1.64},
#  'search_parameters': {'engine': 'google_flights',
#   'hl': 'en',
#   'gl': 'us',
#   'type': '2',
#   'departure_id': 'CDG',
#   'arrival_id': 'MXP',
#   'outbound_date': '2024-11-02',
#   'currency': 'EUR'},
#  'best_flights': [{'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 06:05'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 07:35'},
#      'duration': 90,
#      'airplane': 'Airbus A320',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 4541',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 69 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 69000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 15},
#    'price': 36,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pWTWpRMU5ERWFDZ2lESEJBQ0dnTkZWVkk0SEhDQUh3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIlUyIiwiNDU0MSJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 09:05'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 10:35'},
#      'duration': 90,
#      'airplane': 'Airbus A320',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 3806',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Carbon emissions estimate: 69 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 69000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 15},
#    'price': 36,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pWTWpNNE1EWWFDZ2lESEJBQ0dnTkZWVkk0SEhDQUh3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIlUyIiwiMzgwNiJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 16:55'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 18:20'},
#      'duration': 85,
#      'airplane': 'Airbus A220-300 Passenger',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1730',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'Wi-Fi for a fee',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 67 kg']}],
#    'total_duration': 85,
#    'carbon_emissions': {'this_flight': 67000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 12},
#    'price': 143,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pCUmpFM016QWFDZ2pWYnhBQ0dnTkZWVkk0SEhEQ2V3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIkFGIiwiMTczMCJdXV0='}],
#  'other_flights': [{'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 21:40'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 23:10'},
#      'duration': 90,
#      'airplane': 'Airbus A321',
#      'airline': 'easyJet',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#      'travel_class': 'Economy',
#      'flight_number': 'U2 3812',
#      'legroom': '28 in',
#      'extensions': ['Below average legroom (28 in)',
#       'Carbon emissions estimate: 68 kg'],
#      'often_delayed_by_over_30_min': True}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 68000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 13},
#    'price': 74,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/U2.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pWTWpNNE1USWFDZ2lwT1JBQ0dnTkZWVkk0SEhDMFB3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIlUyIiwiMzgxMiJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 13:00'},
#      'arrival_airport': {'name': 'Josep Tarradellas Barcelona-El Prat Airport',
#       'id': 'BCN',
#       'time': '2024-11-02 14:50'},
#      'duration': 110,
#      'airplane': 'Airbus A320',
#      'airline': 'Vueling',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/VY.png',
#      'travel_class': 'Economy',
#      'flight_number': 'VY 8243',
#      'ticket_also_sold_by': ['Iberia'],
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 85 kg']},
#     {'departure_airport': {'name': 'Josep Tarradellas Barcelona-El Prat Airport',
#       'id': 'BCN',
#       'time': '2024-11-02 15:35'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 17:15'},
#      'duration': 100,
#      'airplane': 'Airbus A321',
#      'airline': 'Vueling',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/VY.png',
#      'travel_class': 'Economy',
#      'flight_number': 'VY 6334',
#      'ticket_also_sold_by': ['Iberia'],
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 82 kg']}],
#    'layovers': [{'duration': 45,
#      'name': 'Josep Tarradellas Barcelona-El Prat Airport',
#      'id': 'BCN'}],
#    'total_duration': 255,
#    'carbon_emissions': {'this_flight': 169000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 182},
#    'price': 100,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/VY.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'Ticket changes for a fee'],
#    'booking_token': ''},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 08:05'},
#      'arrival_airport': {'name': 'Amsterdam Airport Schiphol',
#       'id': 'AMS',
#       'time': '2024-11-02 09:30'},
#      'duration': 85,
#      'airplane': 'Airbus A320',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1340',
#      'ticket_also_sold_by': ['KLM'],
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Wi-Fi for a fee',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 56 kg']},
#     {'departure_airport': {'name': 'Amsterdam Airport Schiphol',
#       'id': 'AMS',
#       'time': '2024-11-02 14:35'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 16:10'},
#      'duration': 95,
#      'airplane': 'Boeing 737',
#      'airline': 'KLM',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/KL.png',
#      'travel_class': 'Economy',
#      'flight_number': 'KL 1621',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'Carbon emissions estimate: 88 kg']}],
#    'layovers': [{'duration': 305,
#      'name': 'Amsterdam Airport Schiphol',
#      'id': 'AMS'}],
#    'total_duration': 485,
#    'carbon_emissions': {'this_flight': 146000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 143},
#    'price': 102,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/multi.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': ''},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 15:00'},
#      'arrival_airport': {'name': 'Zurich Airport',
#       'id': 'ZRH',
#       'time': '2024-11-02 16:15'},
#      'duration': 75,
#      'airplane': 'Embraer 195 E2',
#      'airline': 'SWISS',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LX 639',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 69 kg'],
#      'often_delayed_by_over_30_min': True},
#     {'departure_airport': {'name': 'Zurich Airport',
#       'id': 'ZRH',
#       'time': '2024-11-02 17:20'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 18:15'},
#      'duration': 55,
#      'airplane': 'Embraer 195 E2',
#      'airline': 'SWISS',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#      'travel_class': 'Economy',
#      'flight_number': 'LX 1622',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 46 kg'],
#      'often_delayed_by_over_30_min': True}],
#    'layovers': [{'duration': 65, 'name': 'Zurich Airport', 'id': 'ZRH'}],
#    'total_duration': 195,
#    'carbon_emissions': {'this_flight': 116000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 93},
#    'price': 131,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/LX.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': ''},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 07:10'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 08:40'},
#      'duration': 90,
#      'airplane': 'Airbus A320',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 4148',
#      'legroom': '29 in',
#      'extensions': ['Below average legroom (29 in)',
#       'Wi-Fi for a fee',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 71 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 72000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 20},
#    'price': 143,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pCUmpReE5EZ2FDZ2pWYnhBQ0dnTkZWVkk0SEhEQ2V3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIkFGIiwiNDE0OCJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 09:05'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 10:35'},
#      'duration': 90,
#      'airplane': 'Embraer 190',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1830',
#      'legroom': '31 in',
#      'extensions': ['Average legroom (31 in)',
#       'Carbon emissions estimate: 101 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 101000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 68},
#    'price': 143,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pCUmpFNE16QWFDZ2pWYnhBQ0dnTkZWVkk0SEhEQ2V3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIkFGIiwiMTgzMCJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 10:30'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 12:00'},
#      'duration': 90,
#      'airplane': 'Embraer 190',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1130',
#      'legroom': '31 in',
#      'extensions': ['Average legroom (31 in)',
#       'Carbon emissions estimate: 101 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 101000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 68},
#    'price': 143,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pCUmpFeE16QWFDZ2pWYnhBQ0dnTkZWVkk0SEhEQ2V3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIkFGIiwiMTEzMCJdXV0='},
#   {'flights': [{'departure_airport': {'name': 'Paris Charles de Gaulle Airport',
#       'id': 'CDG',
#       'time': '2024-11-02 13:45'},
#      'arrival_airport': {'name': 'Milan Malpensa Airport',
#       'id': 'MXP',
#       'time': '2024-11-02 15:15'},
#      'duration': 90,
#      'airplane': 'Airbus A321',
#      'airline': 'Air France',
#      'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#      'travel_class': 'Economy',
#      'flight_number': 'AF 1330',
#      'legroom': '30 in',
#      'extensions': ['Average legroom (30 in)',
#       'In-seat USB outlet',
#       'Carbon emissions estimate: 74 kg']}],
#    'total_duration': 90,
#    'carbon_emissions': {'this_flight': 75000,
#     'typical_for_this_route': 60000,
#     'difference_percent': 25},
#    'price': 143,
#    'type': 'One way',
#    'airline_logo': 'https://www.gstatic.com/flights/airline_logos/70px/AF.png',
#    'extensions': ['Checked baggage for a fee',
#     'Fare non-refundable, taxes may be refundable',
#     'No ticket changes'],
#    'booking_token': 'WyJDalJJU1hSa1IyWm9PRjlzZURoQlF6STVibEZDUnkwdExTMHRMUzB0TFMxd2FtWjNOMEZCUVVGQlIySlVSMDVaVGtKSmFtOUJFZ1pCUmpFek16QWFDZ2pWYnhBQ0dnTkZWVkk0SEhEQ2V3PT0iLFtbIkNERyIsIjIwMjQtMTEtMDIiLCJNWFAiLG51bGwsIkFGIiwiMTMzMCJdXV0='}],
#  'price_insights': {'lowest_price': 36,
#   'price_level': 'typical',
#   'typical_price_range': [25, 75],
#   'price_history': [[1719871200, 40],
#    [1719957600, 40],
#    [1720044000, 40],
#    [1720130400, 40],
#    [1720216800, 40],
#    [1720303200, 40],
#    [1720389600, 40],
#    [1720476000, 40],
#    [1720562400, 40],
#    [1720648800, 41],
#    [1720735200, 39],
#    [1720821600, 39],
#    [1720908000, 39],
#    [1720994400, 39],
#    [1721080800, 39],
#    [1721167200, 39],
#    [1721253600, 39],
#    [1721340000, 39],
#    [1721426400, 39],
#    [1721512800, 39],
#    [1721599200, 31],
#    [1721685600, 31],
#    [1721772000, 31],
#    [1721858400, 31],
#    [1721944800, 31],
#    [1722031200, 35],
#    [1722117600, 35],
#    [1722204000, 35],
#    [1722290400, 35],
#    [1722376800, 35],
#    [1722463200, 35],
#    [1722549600, 35],
#    [1722636000, 35],
#    [1722722400, 35],
#    [1722808800, 35],
#    [1722895200, 35],
#    [1722981600, 35],
#    [1723068000, 35],
#    [1723154400, 35],
#    [1723240800, 35],
#    [1723327200, 35],
#    [1723413600, 35],
#    [1723500000, 35],
#    [1723586400, 35],
#    [1723672800, 35],
#    [1723759200, 35],
#    [1723845600, 35],
#    [1723932000, 35],
#    [1724018400, 35],
#    [1724104800, 35],
#    [1724191200, 35],
#    [1724277600, 35],
#    [1724364000, 35],
#    [1724450400, 35],
#    [1724536800, 35],
#    [1724623200, 35],
#    [1724709600, 35],
#    [1724796000, 35],
#    [1724882400, 35],
#    [1724968800, 35],
#    [1725055200, 36]]}}

# %%
### parse travel plan ---> partenza da Milano (MXP, LIN, BGY) a Berlino (BER) -- andata e ritorno date
### chiamata api -----> lista opzioni voli [.....]
### lista opzioni, travel_plan -----> LLM ------> enriched travel plan (sui voli ora e prezzo)

# %% [markdown]
# ## 3b. From travel plan to check hotels

# %%
GPTRAVEL_PROMPT_HOTEL_QUERY_TEMPLATE = """
You are an intelligent travel planner.

The user is departing plans to go to {destination}. This is what the user expressed: "{travel_text}".
You have previously generated the following travel plan: {travel_plan}
Given this in mind, we need to get the information required for calling SerpAPI for the search hotel accomodations. 
For each city of the plan, give in output the search api requests for each night of the travel. 

Important; if a city is comprised in one or more days in day_plans, just create one query input for that.
"""

class HotelSearchParameters(BaseModel):
    """Hotel Search parameters"""
    q: str = Field(description="Parameter defines the city of the accodomation. You can use anything that you would use in a regular Google Hotels search.")
    check_in_date: datetime.date = Field(description="Parameter defines the check-in date. The format is YYYY-MM-DD. e.g. 2024-08-31")
    check_out_date: datetime.date = Field(description="Parameter defines the check-out date. The format is YYYY-MM-DD. e.g. 2024-09-01")
    adults: Optional[int] = Field(description="Parameter defines the number of adults. Default to 2.")
    children: Optional[int] = Field(description="Parameter defines the number of children. Default to 0.")
    children_ages: Optional[List[int]] = Field(description="Parameter defines the ages of children. The age range is from 1 to 17, with children who haven't reached 1 year old being considered as 1. Example for single child only 5. Example for multiple children (seperated by comma ,): [5,8,10]")
    max_price: Optional[int] = Field(description="Parameter defines the upper bound of price range.")
    

class HotelSearchInputs(BaseModel):
    """Search Inputs for Travel accomodations"""
    search_list: List[HotelSearchParameters] = Field(description='List of hotel search parameters for each travel night')

# %%
llm_search_hotel = ChatOpenAI(model="gpt-4o")


prompt_template_search_hotel = PromptTemplate(
    input_variables=["destination", "travel_text", "travel_plan"],
    template=GPTRAVEL_PROMPT_HOTEL_QUERY_TEMPLATE
)


structured_llm_search_hotel = llm_search_hotel.with_structured_output(HotelSearchInputs)

# %%
params_search_hotel = {
    "destination": user_input['destination'],
    "travel_text": user_input['travel_text'],
    "travel_plan": travel_plan_output.json()
}

print(prompt_template_search_hotel.format(**params_search_hotel))
# Out:
# You are an intelligent travel planner.
#
# The user is departing plans to go to Paris. This is what the user expressed: "I wanna visit Paris with my girlfriend in a romantic weekend. I'd love to impress her but at the same time I'd love to visit the best places of the city. I would like to sleep also in a good place, maximum 300 euros per night.".
# You have previously generated the following travel plan: {"day_plans": [{"date": "2024-10-31", "activities": [{"time": "2024-10-31T10:00:00", "place": "Eiffel Tower", "description": "Start your romantic weekend with a visit to the iconic Eiffel Tower. Take an elevator ride to the top for a breathtaking view of Paris."}, {"time": "2024-10-31T12:00:00", "place": "Champs-\u00c9lys\u00e9es", "description": "Stroll down the famous avenue, stopping by luxury boutiques and cafes. Enjoy some shopping and people-watching."}, {"time": "2024-10-31T15:00:00", "place": "Louvre Museum", "description": "Visit the world's largest art museum and a historic monument in Paris. Don't miss the Mona Lisa and the Venus de Milo."}, {"time": "2024-10-31T18:00:00", "place": "Seine River", "description": "Take a romantic evening cruise on the Seine River. Enjoy the beautiful views of the city's landmarks illuminated at night."}]}, {"date": "2024-11-01", "activities": [{"time": "2024-11-01T10:00:00", "place": "Montmartre", "description": "Explore the charming district of Montmartre. Visit the Basilica of the Sacr\u00e9-C\u0153ur and enjoy the artistic atmosphere."}, {"time": "2024-11-01T12:00:00", "place": "Le Marais", "description": "Wander through the historic Le Marais district. Discover its narrow streets, trendy boutiques, and historic buildings."}, {"time": "2024-11-01T15:00:00", "place": "Notre-Dame Cathedral", "description": "Visit the stunning Notre-Dame Cathedral. Admire its Gothic architecture and explore its interior."}, {"time": "2024-11-01T18:00:00", "place": "Luxembourg Gardens", "description": "Take a romantic walk in the beautiful Luxembourg Gardens. Relax by the fountains and enjoy the serene environment."}]}, {"date": "2024-11-02", "activities": [{"time": "2024-11-02T10:00:00", "place": "Mus\u00e9e d'Orsay", "description": "Visit the Mus\u00e9e d'Orsay, known for its impressive collection of Impressionist and Post-Impressionist masterpieces."}, {"time": "2024-11-02T12:00:00", "place": "Saint-Germain-des-Pr\u00e9s", "description": "Explore the historic Saint-Germain-des-Pr\u00e9s neighborhood. Visit its famous cafes and bookstores."}, {"time": "2024-11-02T15:00:00", "place": "Palace of Versailles", "description": "Take a half-day trip to the Palace of Versailles. Explore the opulent palace and its stunning gardens."}, {"time": "2024-11-02T18:00:00", "place": "Montparnasse Tower", "description": "End your romantic weekend with a visit to the Montparnasse Tower. Enjoy a panoramic view of Paris at sunset."}]}]}
# Given this in mind, we need to get the information required for calling SerpAPI for the search hotel accomodations.
# For each city of the plan, give in output the search api requests for each night of the travel.
#
# Important; if a city is comprised in one or more days in day_plans, just create one query input for that.

# %%
search_flights_input_hotels_output = structured_llm_search_hotel.invoke(
    prompt_template_search_hotel.format(**params_search_hotel)
)

# %%
search_flights_input_hotels_output
# Out:
# HotelSearchInputs(search_list=[HotelSearchParameters(q='Paris', check_in_date=datetime.date(2024, 10, 31), check_out_date=datetime.date(2024, 11, 2), adults=2, children=None, children_ages=None, max_price=300)])

# %%
search_hotels_inputs = json.loads(search_flights_input_hotels_output.json())

search_hotels_inputs
# Out:
# {'search_list': [{'q': 'Paris',
#    'check_in_date': '2024-10-31',
#    'check_out_date': '2024-11-02',
#    'adults': 2,
#    'children': None,
#    'children_ages': None,
#    'max_price': 300}]}

# %%
FIXED_HOTEL_PARAMS = {
    "currency": "EUR",
    "sort_by": "3",
    "api_key": os.environ["SERPAPI_KEY"],
    "engine": "google_hotels"
}

hotel_queries = []

for queries in search_hotels_inputs['search_list']:
    
    hotel_search_params = queries | FIXED_HOTEL_PARAMS

    hotel_search = GoogleSearch(hotel_search_params)
    hotel_search_results = hotel_search.get_dict()

    hotel_queries.append(hotel_search_results)

# %%
hotel_queries[0]
# Out:
# {'search_metadata': {'id': '66d3338ba8827832a4c10a33',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/7a6f42623ecab92a/66d3338ba8827832a4c10a33.json',
#   'created_at': '2024-08-31 15:15:23 UTC',
#   'processed_at': '2024-08-31 15:15:23 UTC',
#   'google_hotels_url': 'https://www.google.com/_/TravelFrontendUi/data/batchexecute?rpcids=AtySUc&source-path=/travel/search&hl=en&gl=us&rt=c&soc-app=162&soc-platform=1&soc-device=1',
#   'raw_html_file': 'https://serpapi.com/searches/7a6f42623ecab92a/66d3338ba8827832a4c10a33.html',
#   'prettify_html_file': 'https://serpapi.com/searches/7a6f42623ecab92a/66d3338ba8827832a4c10a33.prettify',
#   'total_time_taken': 2.04},
#  'search_parameters': {'engine': 'google_hotels',
#   'q': 'Paris',
#   'gl': 'us',
#   'hl': 'en',
#   'currency': 'EUR',
#   'check_in_date': '2024-10-31',
#   'check_out_date': '2024-11-02',
#   'adults': 2,
#   'children': 0,
#   'sort_by': '3',
#   'max_price': '300'},
#  'brands': [{'id': 33,
#    'name': 'Accor Live Limitless',
#    'children': [{'id': 85, 'name': '25hours'},
#     {'id': 15, 'name': 'Adagio'},
#     {'id': 278, 'name': 'Adagio Access'},
#     {'id': 375, 'name': 'Greet'},
#     {'id': 92, 'name': 'Hotel F1'},
#     {'id': 21, 'name': 'Ibis'},
#     {'id': 13, 'name': 'Ibis Budget'},
#     {'id': 103, 'name': 'Ibis Styles'},
#     {'id': 279, 'name': 'JO&JOE'},
#     {'id': 94, 'name': 'Mama Shelter'},
#     {'id': 91, 'name': 'Mercure'},
#     {'id': 142, 'name': 'MGallery'},
#     {'id': 47, 'name': 'Novotel'},
#     {'id': 69, 'name': 'Onefinestay'},
#     {'id': 90, 'name': 'Pullman Hotels and Resorts'},
#     {'id': 268, 'name': 'Raffles'},
#     {'id': 273, 'name': 'SO/'},
#     {'id': 84, 'name': 'Sofitel'},
#     {'id': 374, 'name': 'Tribe'}]},
#   {'id': 98, 'name': 'B&B Hotels'},
#   {'id': 18,
#    'name': 'Best Western International',
#    'children': [{'id': 155, 'name': 'Best Western'},
#     {'id': 104, 'name': 'Best Western Plus'},
#     {'id': 105, 'name': 'Best Western Premier'},
#     {'id': 254, 'name': 'Best Western Premier Collection'},
#     {'id': 255, 'name': 'Best Western Signature Collection'},
#     {'id': 108, 'name': 'SureStay'},
#     {'id': 109, 'name': 'SureStay Collection'}]},
#   {'id': 247, 'name': 'Campanile'},
#   {'id': 20,
#    'name': 'Choice Hotels',
#    'children': [{'id': 27, 'name': 'Comfort Inn'}]},
#   {'id': 289, 'name': 'Four Seasons'},
#   {'id': 245, 'name': 'Golden Tulip'},
#   {'id': 28,
#    'name': 'Hilton Honors',
#    'children': [{'id': 114, 'name': 'Canopy'},
#     {'id': 151, 'name': 'Curio Collection'},
#     {'id': 115, 'name': 'Hampton by Hilton'},
#     {'id': 71, 'name': 'Hilton Garden Inn'},
#     {'id': 54, 'name': 'Hilton Hotels & Resorts'},
#     {'id': 285, 'name': 'Tapestry Collection'}]},
#   {'id': 37,
#    'name': 'Hyatt',
#    'children': [{'id': 288, 'name': 'Hyatt'},
#     {'id': 122, 'name': 'Hyatt Regency'},
#     {'id': 118, 'name': 'Park Hyatt'},
#     {'id': 262, 'name': 'Unbound Collection'}]},
#   {'id': 17,
#    'name': 'IHG Hotels & Resorts',
#    'children': [{'id': 42, 'name': 'Crowne Plaza'},
#     {'id': 64, 'name': 'Holiday Inn'},
#     {'id': 56, 'name': 'Holiday Inn Express'},
#     {'id': 87, 'name': 'Hotel Indigo'},
#     {'id': 2, 'name': 'InterContinental Hotels & Resorts'},
#     {'id': 127, 'name': 'Kimpton Hotels & Restaurants'},
#     {'id': 298, 'name': 'Voco'}]},
#   {'id': 249, 'name': 'Kyriad'},
#   {'id': 46,
#    'name': 'Marriott Bonvoy',
#    'children': [{'id': 128, 'name': 'AC Hotels'},
#     {'id': 258, 'name': 'Bvlgari'},
#     {'id': 86, 'name': 'Courtyard by Marriott'},
#     {'id': 72, 'name': 'Le Méridien'},
#     {'id': 61, 'name': 'Marriott Hotels & Resorts'},
#     {'id': 129, 'name': 'Moxy'},
#     {'id': 131, 'name': 'Renaissance Hotels'},
#     {'id': 75, 'name': 'Residence Inn by Marriott'},
#     {'id': 143, 'name': 'The Luxury Collection'},
#     {'id': 154, 'name': 'Tribute Portfolio'},
#     {'id': 39, 'name': 'Westin Hotels & Resorts'}]},
#   {'id': 174,
#    'name': 'Melia Hotels International',
#    'children': [{'id': 178, 'name': 'Melia Hotels & Resorts'}]},
#   {'id': 167, 'name': 'Motel One'},
#   {'id': 169,
#    'name': 'NH Hotel Group',
#    'children': [{'id': 170, 'name': 'NH Hotels'}]},
#   {'id': 252, 'name': 'Premiere Classe'},
#   {'id': 80,
#    'name': 'Radisson Hotel Group',
#    'children': [{'id': 79, 'name': 'Radisson Blu'},
#     {'id': 391, 'name': 'Radisson Individuals'}]}],
#  'properties': [{'type': 'hotel',
#    'name': 'hotelF1 Paris Porte de Montreuil',
#    'description': 'Modern lodging with free WiFi & basic rooms with shared bathrooms, plus in some cases, bunk beds.',
#    'link': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=3488&merchantid=seo-maps-FR-3488&sourceid=aw-cen&utm_medium=seo%20maps&utm_source=google%20Maps&utm_campaign=seo%20maps',
#    'gps_coordinates': {'latitude': 48.8557601, 'longitude': 2.4161588},
#    'check_in_time': '2:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€41',
#     'extracted_lowest': 41,
#     'before_taxes_fees': '€33',
#     'extracted_before_taxes_fees': 33},
#    'total_rate': {'lowest': '€82',
#     'extracted_lowest': 82,
#     'before_taxes_fees': '€65',
#     'extracted_before_taxes_fees': 65},
#    'nearby_places': [{'name': 'Nation',
#      'transportations': [{'type': 'Taxi', 'duration': '9 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '23 min'},
#       {'type': 'Public transport', 'duration': '1 hr 3 min'}]},
#     {'name': "Adil's",
#      'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#    'hotel_class': '1-star tourist hotel',
#    'extracted_hotel_class': 1,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/proxy/ETJipmAdGx68KopVumrrU-6hf_YzaFd0h1hBDGOnJD0nBQ5N6Xa_jtPRc5k8nFNVoTHil3Urgmfqn86drkr3tWhvYZyA0t1FjRvhNm7AQuXcTKwXG0lqGb45Cpk2vJ_QfHVATuO-oEXmsRg9XT4xxUECj0NSwI4=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/33/332043/332043a_hb_ro_004.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNo1OoJsxXoky3vOcCaOZByN9XNgOw9xqG9my9W=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNo1OoJsxXoky3vOcCaOZByN9XNgOw9xqG9my9W=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP0GBjmhdhgs-RYaULN6m053a0W2-SqZvQrctDw=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP0GBjmhdhgs-RYaULN6m053a0W2-SqZvQrctDw=s10000'},
#     {'thumbnail': 'https://lh6.googleusercontent.com/proxy/8srzVrisHhgWAkN1AZro0BPwZrpjUm30x-BGOSHz7BF2Jy5nkPE65r4v8d4a1qnFucCbP7MXKygC3iNqM1OGa4USRF92hzY_UdA6f8RWVsgTjFIF87aERfwvMiZ9rVcT9eaSDcV1iqzgmlFLBXEVAOLHFM189xg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/33/332043/332043a_hb_a_013.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/CtJ1gKLTvKQ05lOQs53koDDOOIW64hb7mETblrnLGSafEvnmBig6-NnIbeM2GYfv3H9DHEhWwgsRK74Pl7RQhoFLBUi3kPffjpfO4s9OmPjf7FGXzsAb8maZNeN1O9DfY4TE8f6HNi2rOEw78VSIo2MRd5fnMnQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAD7nVwQFAHAlyNVqzJbYVYvdQZV2Qj0'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNwruXotx7cU8_aKEDGKaXj3lsAddyg8Alec-HM=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNwruXotx7cU8_aKEDGKaXj3lsAddyg8Alec-HM=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOEGeRqH6WQu_R3NmCBTcznhkq7fJ4FgjOWr1se=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOEGeRqH6WQu_R3NmCBTcznhkq7fJ4FgjOWr1se=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMnmFgtoyzQqEuR0oWa-xjBYfIRadnzh1lqwhGz=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMnmFgtoyzQqEuR0oWa-xjBYfIRadnzh1lqwhGz=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN_GARjReom_9l2OHRoytziT9uWy1bZ_57ttzxI=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipN_GARjReom_9l2OHRoytziT9uWy1bZ_57ttzxI=s10000'}],
#    'overall_rating': 3.4,
#    'reviews': 1999,
#    'ratings': [{'stars': 5, 'count': 608},
#     {'stars': 4, 'count': 449},
#     {'stars': 3, 'count': 357},
#     {'stars': 2, 'count': 214},
#     {'stars': 1, 'count': 371}],
#    'location_rating': 3.4,
#    'reviews_breakdown': [{'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 328,
#      'positive': 87,
#      'negative': 193,
#      'neutral': 48},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 363,
#      'positive': 215,
#      'negative': 119,
#      'neutral': 29},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 392,
#      'positive': 226,
#      'negative': 121,
#      'neutral': 45},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 334,
#      'positive': 221,
#      'negative': 90,
#      'neutral': 23},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 219,
#      'positive': 54,
#      'negative': 127,
#      'neutral': 38},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 217,
#      'positive': 134,
#      'negative': 29,
#      'neutral': 54}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Parking ($)',
#     'Air conditioning',
#     'Pet-friendly',
#     'Accessible',
#     'Child-friendly'],
#    'property_token': 'ChcI7fPIrt25wolZGgsvZy8xdGZ6bG44YhAB',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChcI7fPIrt25wolZGgsvZy8xdGZ6bG44YhAB&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'hotelF1 Paris Saint-Ouen - Marché aux Puces',
#    'description': 'Humble option offering basic rooms with shared bathrooms & flat-screen TVs, plus free Wi-Fi.',
#    'link': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=2539&merchantid=seo-maps-FR-2539&sourceid=aw-cen&utm_medium=seo%20maps&utm_source=google%20Maps&utm_campaign=seo%20maps',
#    'gps_coordinates': {'latitude': 48.901185999999996, 'longitude': 2.332576},
#    'check_in_time': '2:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€42',
#     'extracted_lowest': 42,
#     'before_taxes_fees': '€33',
#     'extracted_before_taxes_fees': 33},
#    'total_rate': {'lowest': '€84',
#     'extracted_lowest': 84,
#     'before_taxes_fees': '€67',
#     'extracted_before_taxes_fees': 67},
#    'nearby_places': [{'name': 'Porte de Clichy',
#      'transportations': [{'type': 'Taxi', 'duration': '6 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '30 min'},
#       {'type': 'Public transport', 'duration': '1 hr 2 min'}]},
#     {'name': 'L’avenue - Restaurant Bar Lounge',
#      'transportations': [{'type': 'Walking', 'duration': '4 min'}]}],
#    'hotel_class': '1-star tourist hotel',
#    'extracted_hotel_class': 1,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMNinoo33osDKh7BI927Q3aM4wOGc9MUptxxrTL=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMNinoo33osDKh7BI927Q3aM4wOGc9MUptxxrTL=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMZvx7DcGkabjLCzxTHCmQ4489iLRgN33cEgIVQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMZvx7DcGkabjLCzxTHCmQ4489iLRgN33cEgIVQ=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNUHVDtDgVHlz4U_vvzlp_rOr6P0fEH7dGFWemP=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNUHVDtDgVHlz4U_vvzlp_rOr6P0fEH7dGFWemP=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPq3U-Qh-hpmSmpYbAaXTBo20NlJ6nNWV3dmuUg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPq3U-Qh-hpmSmpYbAaXTBo20NlJ6nNWV3dmuUg=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP-GhXmh2SaErik4eicEndno6At31Fx4WAwdUt7=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP-GhXmh2SaErik4eicEndno6At31Fx4WAwdUt7=s10000'},
#     {'thumbnail': 'https://lh6.googleusercontent.com/proxy/pkAl3ZkhKk6xp_1Rm7C50DOeVEFcTr5UGiuXtdHuaIEmhAX3cOWeyiOm6tRUtHsRE5_gY_jLgLUjp492qjHe_yOx4Q4dRC8muJiAv85UM58q_WGJJ6rD5fmKkkAV6CQJyLx2ySgWUJvUQ3aa9NvG_AbPWolQlYE=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAEp-WgMFALjOZ7mlFYnCAeYSpKOPKA0'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/tzPUa_0eoMOTj3vK4qYGRA2UbqcWR_mJ_IuRilYS_02REzOO5idDucWgyONdo8iBVLLOUDxgbozT9sWcIOI7FQ60-4TfqjcW5YGGJrA6MYXnFTUPNWFgJtcsgqYSfLys7bpe0B6Mqcb-HyyT-2uOYGiK3pv6LbE=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://images.trvl-media.com/lodging/14000000/13450000/13441600/13441534/f6d90b11_z.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/S8huYMuDpPt3VvQQ59RRjhynnJuUyjjjYgdatKMpR9B0vDykUQi06lkLsdy9CUj5s2zhLGf5xnLr7kk99jfdudsAuZxCyj2y95OX11i-UemauzI-hcHifVKm7eIY4Uvb7H1pD3Ealw16qbPa3oq6lPHKfcWHDoQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAHvxVwQFAE4yhycHn0P5c64JqWD86lU'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOJifRsjvrbM5d5ImJoKaASE_SWz__PtfWvUfH0=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOJifRsjvrbM5d5ImJoKaASE_SWz__PtfWvUfH0=s10000'}],
#    'overall_rating': 2.9,
#    'reviews': 4136,
#    'ratings': [{'stars': 5, 'count': 885},
#     {'stars': 4, 'count': 772},
#     {'stars': 3, 'count': 752},
#     {'stars': 2, 'count': 526},
#     {'stars': 1, 'count': 1201}],
#    'location_rating': 3.3,
#    'reviews_breakdown': [{'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 800,
#      'positive': 144,
#      'negative': 535,
#      'neutral': 121},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 915,
#      'positive': 319,
#      'negative': 497,
#      'neutral': 99},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 673,
#      'positive': 132,
#      'negative': 466,
#      'neutral': 75},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 864,
#      'positive': 319,
#      'negative': 412,
#      'neutral': 133},
#     {'name': 'Safety',
#      'description': 'Safety',
#      'total_mentioned': 236,
#      'positive': 46,
#      'negative': 160,
#      'neutral': 30},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 407,
#      'positive': 176,
#      'negative': 154,
#      'neutral': 77}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Parking',
#     'Air conditioning',
#     'Pet-friendly',
#     'Restaurant',
#     'Accessible',
#     'Child-friendly',
#     'Smoke-free property'],
#    'property_token': 'ChgI9qyAz5mJx8qLARoLL2cvMXRoeGtjcDEQAQ',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChgI9qyAz5mJx8qLARoLL2cvMXRoeGtjcDEQAQ&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'hotelF1 Paris Porte de Châtillon',
#    'description': 'Simple rooms in a laid-back property offering complimentary Wi-Fi & bright communal areas.',
#    'link': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=5010&merchantid=seo-maps-FR-5010&sourceid=aw-cen&utm_medium=seo%20maps&utm_source=google%20Maps&utm_campaign=seo%20maps',
#    'gps_coordinates': {'latitude': 48.8227719, 'longitude': 2.3165416},
#    'check_in_time': '2:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€48',
#     'extracted_lowest': 48,
#     'before_taxes_fees': '€39',
#     'extracted_before_taxes_fees': 39},
#    'total_rate': {'lowest': '€95',
#     'extracted_lowest': 95,
#     'before_taxes_fees': '€77',
#     'extracted_before_taxes_fees': 77},
#    'nearby_places': [{'name': 'Catacombs of Paris',
#      'transportations': [{'type': 'Taxi', 'duration': '9 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '34 min'},
#       {'type': 'Public transport', 'duration': '1 hr 1 min'}]},
#     {'name': "HUB'AO - Restaurant Paris 14",
#      'transportations': [{'type': 'Walking', 'duration': '7 min'}]}],
#    'hotel_class': '1-star tourist hotel',
#    'extracted_hotel_class': 1,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPoEqwB8kAaUQ4apqCEYV8zmpJjT8yeelju5snc=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPoEqwB8kAaUQ4apqCEYV8zmpJjT8yeelju5snc=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOV0fY8hyyiXZdFC-I8Qwf9YHFfPZ8hT9Q6xCk=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOV0fY8hyyiXZdFC-I8Qwf9YHFfPZ8hT9Q6xCk=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOa2DdxCdxXifZKNSyF-1a9-HgZCC9YiBZD0ao=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOa2DdxCdxXifZKNSyF-1a9-HgZCC9YiBZD0ao=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPWhmyAHEsGut7OyWPdSdBzmh9GKs1_q_11xa0=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPWhmyAHEsGut7OyWPdSdBzmh9GKs1_q_11xa0=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMir7l1LPQp_3B-oDFcusU386lSG1ASkRs6ygM=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMir7l1LPQp_3B-oDFcusU386lSG1ASkRs6ygM=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipO_bI_8E0YkHIElkh-ykjx-HPwLcipvbXll47Q=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipO_bI_8E0YkHIElkh-ykjx-HPwLcipvbXll47Q=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOltDdMz-lZ_F4lfRT943_5wOEWa2m9p95XBU4=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOltDdMz-lZ_F4lfRT943_5wOEWa2m9p95XBU4=s10000'},
#     {'thumbnail': 'https://lh4.googleusercontent.com/proxy/69xN8_ml3LbPNk_1P8I30ncSitp_YrumkMZVFfXRDqhE_C9AEet7-bW2n-1ifMAaCSWt5J5IKFdjAHAZwjvfsU6YXIHJOWOvGZZHA5Htg2iDYdXFcpM90IhYrPmEQVuLFRepD7R8bmEWIf6LJN_KqeRQ0z8ANjQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://images.trvl-media.com/lodging/14000000/13450000/13442200/13442171/5b292cb1_z.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNtdW58Wl5xJFusXoU7XBMIsVZgFcuCSksxyXc=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNtdW58Wl5xJFusXoU7XBMIsVZgFcuCSksxyXc=s10000'}],
#    'overall_rating': 3.5,
#    'reviews': 4386,
#    'ratings': [{'stars': 5, 'count': 1251},
#     {'stars': 4, 'count': 1256},
#     {'stars': 3, 'count': 903},
#     {'stars': 2, 'count': 384},
#     {'stars': 1, 'count': 592}],
#    'location_rating': 3.2,
#    'reviews_breakdown': [{'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 896,
#      'positive': 192,
#      'negative': 535,
#      'neutral': 169},
#     {'name': 'Parking',
#      'description': 'Parking',
#      'total_mentioned': 116,
#      'positive': 28,
#      'negative': 61,
#      'neutral': 27},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 787,
#      'positive': 485,
#      'negative': 199,
#      'neutral': 103},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 489,
#      'positive': 127,
#      'negative': 269,
#      'neutral': 93},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 845,
#      'positive': 505,
#      'negative': 215,
#      'neutral': 125},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 605,
#      'positive': 330,
#      'negative': 220,
#      'neutral': 55}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Parking ($)',
#     'Air conditioning',
#     'Pet-friendly',
#     'Accessible',
#     'Child-friendly',
#     'Smoke-free property'],
#    'property_token': 'ChcIiMSA1Iq40qc-GgsvZy8xdGRobDN3YxAB',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChcIiMSA1Iq40qc-GgsvZy8xdGRobDN3YxAB&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'hotelF1 Paris Gennevilliers',
#    'description': 'Colorful dorms & private rooms in a straightforward property offering complimentary Wi-Fi.',
#    'link': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=3176&merchantid=seo-maps-FR-3176&sourceid=aw-cen&utm_medium=seo%20maps&utm_source=google%20Maps&utm_campaign=seo%20maps',
#    'gps_coordinates': {'latitude': 48.918228199999994,
#     'longitude': 2.3070532999999998},
#    'check_in_time': '3:00\u202fPM',
#    'check_out_time': '11:00\u202fAM',
#    'rate_per_night': {'lowest': '€48',
#     'extracted_lowest': 48,
#     'before_taxes_fees': '€39',
#     'extracted_before_taxes_fees': 39},
#    'total_rate': {'lowest': '€95',
#     'extracted_lowest': 95,
#     'before_taxes_fees': '€77',
#     'extracted_before_taxes_fees': 77},
#    'nearby_places': [{'name': 'Asnières-sur-Seine',
#      'transportations': [{'type': 'Taxi', 'duration': '7 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '29 min'},
#       {'type': 'Public transport', 'duration': '1 hr 12 min'}]},
#     {'name': 'Restaurant Fırat m4',
#      'transportations': [{'type': 'Walking', 'duration': '2 min'}]}],
#    'hotel_class': '1-star tourist hotel',
#    'extracted_hotel_class': 1,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPN-aQOrOevgoDLOq9seDUBeqQOb091HdXJiLXM=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPN-aQOrOevgoDLOq9seDUBeqQOb091HdXJiLXM=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNjdbomvFkz2ctqbEUeCmSFM0qkm10vCzvwocCv=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNjdbomvFkz2ctqbEUeCmSFM0qkm10vCzvwocCv=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMw8dU8U7gA8XWscblDtI05QgdJRaT8IhM3KOxQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMw8dU8U7gA8XWscblDtI05QgdJRaT8IhM3KOxQ=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPpqN5ZOGieT4kZIWJm0wzUjlfPFKQQZo5Ri6ev=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPpqN5ZOGieT4kZIWJm0wzUjlfPFKQQZo5Ri6ev=s10000'},
#     {'thumbnail': 'https://lh4.googleusercontent.com/proxy/9vvO64jZmq4kQd-_p6_kUgGfpqldfOMbCYBerJvf46Xe9pcyZOq65XD1ie5jcoay_9as8JVPlDhoUCWra_Z5g1HmWRz5aTRGl0vBhLjB1sQ4PT42NcsaqkBe1I24_gSWZVdPHCzSDt9KPVWYCi5uZ4zde1otHg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/32/329342/329342a_hb_a_003.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOOpFlCTtyoRyoaBxWmLOMRyKYMN5PQ781BAntw=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOOpFlCTtyoRyoaBxWmLOMRyKYMN5PQ781BAntw=s10000'},
#     {'thumbnail': 'https://lh6.googleusercontent.com/proxy/fqHunxuaop8cZ8rSyh_Ogr3dLx0Vu00_9ciIrDZtZfN2W4J3i_hd-t6ROGWEdBuBPQ8yl9ZgwAj5VJ4PMN6rlYDK6yto1qflfCSkSM8X17oAJMlx2y7Kmg4H2pVvfcYNBa5yL4ZDmCRxjACg_cuanWbnKmObgeM=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAAe7YQYFAJi4NUTlkjo14NS82LCIb2c'},
#     {'thumbnail': 'https://lh6.googleusercontent.com/proxy/wyDq5AQn0bQYngCI4uqnlmUG4uBGJrRVx6Q6FvZlcYeXMlkEYfp4ktVLd_daBQXcQXh6g_XNJf7n5nkTel9ebLm9azDvBzhHiyc914Nb-i2TzHB_YAtND3ZOvTPZFBhu19pk89Iz0cHHxVhNNEm500qto3CA1Mk=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://cdn.worldota.net/t/1024x768/content/e3/81/e381124e02a209a5f89a6389a0389193f488d6ed.jpeg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/nAXOaU2fT8duLkmJ9aCYiLEsdWr7iqsuV2VelHMz0JAqqD96Ny2B_BThtVzbJN1x1culGM23NRQchu6ML5qKPG0XaesAY-YqSDM-smUB1BGd4JGV-K7RgbYG7mA7nco0AmFyMjlFjfbZjOelPL_os-cip0rZ8Q=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAKzCTQMFADAAjBTKlh3HSIlS7Xdlz8Q'}],
#    'overall_rating': 2.9,
#    'reviews': 793,
#    'ratings': [{'stars': 5, 'count': 171},
#     {'stars': 4, 'count': 116},
#     {'stars': 3, 'count': 169},
#     {'stars': 2, 'count': 113},
#     {'stars': 1, 'count': 224}],
#    'location_rating': 2.9,
#    'reviews_breakdown': [{'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 147,
#      'positive': 24,
#      'negative': 101,
#      'neutral': 22},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 96,
#      'positive': 15,
#      'negative': 68,
#      'neutral': 13},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 124,
#      'positive': 43,
#      'negative': 67,
#      'neutral': 14},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 67,
#      'positive': 35,
#      'negative': 14,
#      'neutral': 18},
#     {'name': 'Wi-Fi',
#      'description': 'Wi-Fi',
#      'total_mentioned': 11,
#      'positive': 2,
#      'negative': 5,
#      'neutral': 4},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 147,
#      'positive': 47,
#      'negative': 74,
#      'neutral': 26}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Free parking',
#     'Air conditioning',
#     'Pet-friendly',
#     'Accessible',
#     'Child-friendly',
#     'Smoke-free property'],
#    'property_token': 'ChgIxv2Bncaks8TSARoLL2cvMXRkOXZmOHAQAQ',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChgIxv2Bncaks8TSARoLL2cvMXRkOXZmOHAQAQ&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'Trendy Hostel',
#    'description': 'Simple mixed-gender & all-female dorms in a relaxed hostel offering complimentary breakfast & Wi-Fi.',
#    'link': 'https://www.aubergepariseco.com/?utm_source=google&utm_medium=wix_google_business_profile&utm_campaign=6382183506988054258',
#    'gps_coordinates': {'latitude': 48.8148165, 'longitude': 2.3775614},
#    'check_in_time': '3:00\u202fPM',
#    'check_out_time': '11:00\u202fAM',
#    'rate_per_night': {'lowest': '€51',
#     'extracted_lowest': 51,
#     'before_taxes_fees': '€42',
#     'extracted_before_taxes_fees': 42},
#    'total_rate': {'lowest': '€102',
#     'extracted_lowest': 102,
#     'before_taxes_fees': '€84',
#     'extracted_before_taxes_fees': 84},
#    'nearby_places': [{'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '31 min'},
#       {'type': 'Public transport', 'duration': '1 hr 5 min'}]},
#     {'name': "Mam'Asia",
#      'transportations': [{'type': 'Walking', 'duration': '2 min'}]}],
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNp79su3QYEQHgCaEaH7xAC3MEMkG6raWITIoUw=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNp79su3QYEQHgCaEaH7xAC3MEMkG6raWITIoUw=s10000'},
#     {'thumbnail': 'https://lh6.googleusercontent.com/proxy/hez4eitFGyfWd7Scb-1k3rTPVU1Y5R75VXxrsXtOzUHyh0k0W4XbGQGJ8lRg2-108u4nz8aov5zhrR6JH_fh6IRz0MytKDGlARUFQitO4cfbYtTHKn1XIuEyXwWMpFzcIbJB7y3xdwsIfa_HXG03yRcUduzwwUI=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/11/75/83/74/trendy-hostel.jpg?w=1200&h=900&s=1'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPabo0KeS5dR36lPvWECfF03OsXxnkWjhgV6V8H=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPabo0KeS5dR36lPvWECfF03OsXxnkWjhgV6V8H=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOAt5eHaTSpdSiYwz7JYlwbsVIwqSZWSfpQw002=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOAt5eHaTSpdSiYwz7JYlwbsVIwqSZWSfpQw002=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPFX9lsN9Aa_fPVpHFmmMeoZe0wjNLnnO2krIyH=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPFX9lsN9Aa_fPVpHFmmMeoZe0wjNLnnO2krIyH=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOWXbHzH_2q3d7ieYfEmI3ODwsan7xAtziGxk4B=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOWXbHzH_2q3d7ieYfEmI3ODwsan7xAtziGxk4B=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOtJ-v90vCE62KnZdlaZGQtCIRVviXb4a--CJes=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOtJ-v90vCE62KnZdlaZGQtCIRVviXb4a--CJes=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOgy6W5JWbQ6f21UHFgVZcUdrtajlND2OCQACiA=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOgy6W5JWbQ6f21UHFgVZcUdrtajlND2OCQACiA=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipORWnojPyU7I5TNQMhNzyNB0f8fznswYrR4CetD=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipORWnojPyU7I5TNQMhNzyNB0f8fznswYrR4CetD=s10000'}],
#    'overall_rating': 3.3,
#    'reviews': 643,
#    'ratings': [{'stars': 5, 'count': 231},
#     {'stars': 4, 'count': 115},
#     {'stars': 3, 'count': 79},
#     {'stars': 2, 'count': 49},
#     {'stars': 1, 'count': 169}],
#    'location_rating': 3.1,
#    'reviews_breakdown': [{'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 129,
#      'positive': 29,
#      'negative': 84,
#      'neutral': 16},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 146,
#      'positive': 56,
#      'negative': 84,
#      'neutral': 6},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 164,
#      'positive': 92,
#      'negative': 60,
#      'neutral': 12},
#     {'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 82,
#      'positive': 16,
#      'negative': 54,
#      'neutral': 12},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 129,
#      'positive': 78,
#      'negative': 41,
#      'neutral': 10},
#     {'name': 'Breakfast',
#      'description': 'Breakfast',
#      'total_mentioned': 43,
#      'positive': 17,
#      'negative': 20,
#      'neutral': 6}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Air conditioning',
#     'Room service',
#     'Full-service laundry',
#     'Child-friendly'],
#    'property_token': 'ChoIzN3AhpvLgcTXARoNL2cvMTFidHZsYzc4MBAB',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChoIzN3AhpvLgcTXARoNL2cvMTFidHZsYzc4MBAB&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'hotelF1 Paris Saint Denis Stade',
#    'description': 'No-frills budget property offering simple rooms with shared bathrooms, plus an airy breakfast room.',
#    'link': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=3072&merchantid=seo-maps-FR-3072&sourceid=aw-cen&utm_medium=seo%20maps&utm_source=google%20Maps&utm_campaign=seo%20maps',
#    'gps_coordinates': {'latitude': 48.921336600000004, 'longitude': 2.3643262},
#    'check_in_time': '2:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€49',
#     'extracted_lowest': 49,
#     'before_taxes_fees': '€44',
#     'extracted_before_taxes_fees': 44},
#    'total_rate': {'lowest': '€97',
#     'extracted_lowest': 97,
#     'before_taxes_fees': '€88',
#     'extracted_before_taxes_fees': 88},
#    'nearby_places': [{'name': 'La Plaine – Stade de France',
#      'transportations': [{'type': 'Walking', 'duration': '8 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '24 min'},
#       {'type': 'Public transport', 'duration': '33 min'}]},
#     {'name': 'Le France',
#      'transportations': [{'type': 'Walking', 'duration': '6 min'}]}],
#    'hotel_class': '1-star tourist hotel',
#    'extracted_hotel_class': 1,
#    'images': [{'thumbnail': 'https://lh3.googleusercontent.com/proxy/dIXdI5_pk4GK5JQizxgfC_7tQOx0Y-Kr96arPAT6IfrZIVw0qcs6zw5xJaoAkBuvbg_vNscTxn2D_8xi7TP_3OUYeo6XPN4ZXI0OGSjbF7m1NXQLcRjVnZL31zbgQW_SUZ3whJC_Dyb4kuebbI6R8wsQpQUa-fg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://cdn.worldota.net/t/1024x768/content/f2/a9/f2a93a98129514cc8d6e5d0acdd4164435626fbf.JPEG'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMp8es9Ql2Mo4HO8tJZZwN7CmT1tMowq-b2ev3u=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMp8es9Ql2Mo4HO8tJZZwN7CmT1tMowq-b2ev3u=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNbMc3IBo4pHayy1ih_I5JPCCQXzvEm-oxgSESX=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNbMc3IBo4pHayy1ih_I5JPCCQXzvEm-oxgSESX=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/qGbDGdGwrzEHSIYlOzjCkzjxieMV3UJg_YmTwxihjyw2yTbXoPCEtSkV_c4Qxbq9idi9njojAgO9rJxm701hnwaXjUwPSN_5bRDkmZoYodlKINqShJPlxszsPTvN2OwE94ARhQp5fKy5vm1SynUKWFVB8hv3bgI=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAAj4TwMFALcP6LGqaamlVlWETNXc0aw'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/iPWHmSqEN52LhUC-YwVrwu7nTi5x7SWzdjMqDJ34JDUgspFR_vjpJIqBFdY9l0P4b1DAhBGfTe8RSDWkF5qackeXq0S0PRurD3xrKWJZhd2heRpxLJqiTWA54RA77G4dA9VvNNtCuptK-Nt933FPCI75FPZY3XM=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAOJIUQMFACoE-iIQJkVVnxt3ZYA6dqM'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/uHYEtqWr9gW-OTb0XP-QU_PJbSFZt8D25cWGZy2bUKsC_I4bAbpcKzHeEnwYtm60TCzyEhrSknWo22Eyfsisas6l562SFcTjnuUvOmJhUv13-oIbpVFnlA7abprUdV6Pek9ZszJxdRdIsNYf66pEKrWQN7uYNBg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://i.giatamedia.com/m.php?m=AQABAAAAla4KAN10UQMFAG1BnKfjAjcUkR9GfY-wxAs'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMLshaBKN6UV4vlGI2IiRURVruV9QBA32xu81Fc=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMLshaBKN6UV4vlGI2IiRURVruV9QBA32xu81Fc=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMfsFqUkI11T6xvtAmIaDK5ekIvRRShocrDXvUe=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMfsFqUkI11T6xvtAmIaDK5ekIvRRShocrDXvUe=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPJpwxR8Q1j800ieh3ldpBI_e1_GO3E6c46QANc=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPJpwxR8Q1j800ieh3ldpBI_e1_GO3E6c46QANc=s10000'}],
#    'overall_rating': 3.1,
#    'reviews': 804,
#    'ratings': [{'stars': 5, 'count': 185},
#     {'stars': 4, 'count': 158},
#     {'stars': 3, 'count': 166},
#     {'stars': 2, 'count': 107},
#     {'stars': 1, 'count': 188}],
#    'location_rating': 2.9,
#    'reviews_breakdown': [{'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 132,
#      'positive': 24,
#      'negative': 93,
#      'neutral': 15},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 172,
#      'positive': 68,
#      'negative': 89,
#      'neutral': 15},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 108,
#      'positive': 29,
#      'negative': 62,
#      'neutral': 17},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 126,
#      'positive': 67,
#      'negative': 51,
#      'neutral': 8},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 93,
#      'positive': 54,
#      'negative': 17,
#      'neutral': 22},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 151,
#      'positive': 60,
#      'negative': 68,
#      'neutral': 23}],
#    'amenities': ['Free breakfast',
#     'Free Wi-Fi',
#     'Free parking',
#     'Pet-friendly',
#     'Restaurant',
#     'Airport shuttle',
#     'Accessible',
#     'Child-friendly',
#     'Smoke-free property'],
#    'property_token': 'ChcI5auuhIL4gcw3GgsvZy8xdG4wNTM0YxAB',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChcI5auuhIL4gcw3GgsvZy8xdG4wNTM0YxAB&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'Hôtel Le National Clichy Paris',
#    'link': 'http://hotelnationalclichy.com/',
#    'gps_coordinates': {'latitude': 48.8985803, 'longitude': 2.307606},
#    'check_in_time': '3:00\u202fPM',
#    'check_out_time': '11:00\u202fAM',
#    'rate_per_night': {'lowest': '€60',
#     'extracted_lowest': 60,
#     'before_taxes_fees': '€46',
#     'extracted_before_taxes_fees': 46},
#    'total_rate': {'lowest': '€121',
#     'extracted_lowest': 121,
#     'before_taxes_fees': '€92',
#     'extracted_before_taxes_fees': 92},
#    'deal': '30% less than usual',
#    'deal_description': 'Great Deal',
#    'nearby_places': [{'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '32 min'},
#       {'type': 'Public transport', 'duration': '1 hr 11 min'}]},
#     {'name': 'Le Jardin de Clichy',
#      'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#    'hotel_class': '3-star tourist hotel',
#    'extracted_hotel_class': 3,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipM4KKt5yVBAAe5ZzukCUA1snB-cFftpKT5I7G0f=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM4KKt5yVBAAe5ZzukCUA1snB-cFftpKT5I7G0f=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNHuW5rf3S0MKUGo5lGEXP04EehH8iiJLRI0Xc8=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNHuW5rf3S0MKUGo5lGEXP04EehH8iiJLRI0Xc8=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNJQzEtBf7p_oDK-IbJjuS24stehmcLfOwKVwZI=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNJQzEtBf7p_oDK-IbJjuS24stehmcLfOwKVwZI=s10000'},
#     {'thumbnail': 'https://lh6.googleusercontent.com/proxy/VkGwIFbQuAIVmlbBLCOpGAkBvYMW4OzkGqbRn6m5u-bzEJFl12YrlOltboUafnsuSvQOomRXlLXbr0Cg3rNIIKIv8shm-9-OhkAfh83lOzrgQp8xmL1vLjLeemn8Uaa3uy6QQ56pib3k-nVAh6J-OcgaPfktaQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/69/696961/696961a_hb_w_001.jpg'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/nPdVJK_A0UMxX56Azuq5W4POqfxq6v-K65WkkFN_UemXgzUQlUbn7NlsGmIwweQa7R0z6m0Tk6Y4tpZS0DZ0KFeeEPQ2dQckybIDZMKq7ssRc87PHJb34_FjekumSkle590t7kIr4SJerUa1nco1SZLQjDe6YA=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://cdn.worldota.net/t/1024x768/content/f8/b6/f8b6f5991d8f92c2191f5a30241813965ba7c869.jpeg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/ujqr2zZtUrQ8KMkpkjYM9_Ppt2hZkMf_9tSDpQpQ98fkibGAhkQa39lgidTM-K_AaSQoPFaWJYP1rqp8uzWhQLZgKN6fVPqWuD3vq6ELuobXUeXeE--_BQs-HaF0jEoKANEIGBwy8nClJs4JPs1wzxGZ6qn-ayg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/69/696961/696961a_hb_w_009.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNTCP08gW1Qz9EWeLKKL1vLEfQVxx1YCubWa3zE=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNTCP08gW1Qz9EWeLKKL1vLEfQVxx1YCubWa3zE=s10000'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/JQiGFsl3a9AmusmxAQP8QvsqBW4BtKge3IhmY7bU43UhoA4flSvn--PAG6-CP0oAtFqEC2ND2c0xyNDsFiGAxN8_Pg81_9pRPj7tcHkvmdAaQ0jYCIgP8UuERkdDW-oof8ONJNwJNG4bT6IyMTJ3eqG_8FPm2Q=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/69/696961/696961a_hb_ba_006.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNDYsFbedqWdHhdIzGvRV_wFHhFEdITvthyl0am=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNDYsFbedqWdHhdIzGvRV_wFHhFEdITvthyl0am=s10000'}],
#    'overall_rating': 3.5,
#    'reviews': 46,
#    'ratings': [{'stars': 5, 'count': 21},
#     {'stars': 4, 'count': 6},
#     {'stars': 3, 'count': 6},
#     {'stars': 2, 'count': 3},
#     {'stars': 1, 'count': 10}],
#    'location_rating': 3.3,
#    'reviews_breakdown': [{'name': 'Accessibility',
#      'description': 'Accessibility',
#      'total_mentioned': 5,
#      'positive': 0,
#      'negative': 3,
#      'neutral': 2},
#     {'name': 'Air Conditioning',
#      'description': 'Air conditioning',
#      'total_mentioned': 5,
#      'positive': 0,
#      'negative': 2,
#      'neutral': 3},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 10,
#      'positive': 3,
#      'negative': 4,
#      'neutral': 3},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 15,
#      'positive': 10,
#      'negative': 3,
#      'neutral': 2},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 6,
#      'positive': 6,
#      'negative': 0,
#      'neutral': 0},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 11,
#      'positive': 9,
#      'negative': 0,
#      'neutral': 2}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Bar',
#     'Restaurant',
#     'Business centre',
#     'Smoke-free property'],
#    'property_token': 'ChoIhpHot6rpoJn3ARoNL2cvMTFiNl9id2ZmchAB',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChoIhpHot6rpoJn3ARoNL2cvMTFiNl9id2ZmchAB&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'Hôtel Europe BLV',
#    'description': 'Low-key rooms with flat-screens in a relaxed 11th arr. property featuring complimentary Wi-Fi.',
#    'link': 'https://www.hoteleuropeblv.com/',
#    'gps_coordinates': {'latitude': 48.8707916, 'longitude': 2.3767611},
#    'check_in_time': '3:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€58',
#     'extracted_lowest': 58,
#     'before_taxes_fees': '€47',
#     'extracted_before_taxes_fees': 47},
#    'total_rate': {'lowest': '€117',
#     'extracted_lowest': 117,
#     'before_taxes_fees': '€94',
#     'extracted_before_taxes_fees': 94},
#    'deal': '24% less than usual',
#    'deal_description': 'Deal',
#    'nearby_places': [{'name': 'Belleville',
#      'transportations': [{'type': 'Walking', 'duration': '3 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '36 min'},
#       {'type': 'Public transport', 'duration': '54 min'}]},
#     {'name': 'New Hawaienne',
#      'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#    'hotel_class': '2-star tourist hotel',
#    'extracted_hotel_class': 2,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPct9hii7ngx5WF9Lb_Cm1V4jgoY5BAC368YwnE=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPct9hii7ngx5WF9Lb_Cm1V4jgoY5BAC368YwnE=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMiHOyFvkhpzoMCTg86MUy71TpOKCGTA6J6HOzQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMiHOyFvkhpzoMCTg86MUy71TpOKCGTA6J6HOzQ=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPwga3CquExg7CMjNvAhK2yKHLl-evWcFIOQVgz=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPwga3CquExg7CMjNvAhK2yKHLl-evWcFIOQVgz=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipM27FatjZOePqgdRakeQkR19hSpcCsq_QvwFthj=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipM27FatjZOePqgdRakeQkR19hSpcCsq_QvwFthj=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMBTJjIMfKQFWzKtSXJlXdbhi2xA-dzcaWKOClp=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMBTJjIMfKQFWzKtSXJlXdbhi2xA-dzcaWKOClp=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP17scGkHzaNmwwPBIw-39lCJ2Epg8NHxCfokJO=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP17scGkHzaNmwwPBIw-39lCJ2Epg8NHxCfokJO=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN3tA8vR7XFmiJH5YF0f732Kf1-tOo_UA4Eqeb8=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipN3tA8vR7XFmiJH5YF0f732Kf1-tOo_UA4Eqeb8=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipOtYGSAQGge4OmC-1iKucSqiVazLfIR-PaVQsf_=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipOtYGSAQGge4OmC-1iKucSqiVazLfIR-PaVQsf_=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPnhrR1Yr0IqO6vdIIV7MHuTZkdBtaAbHU45uD0=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPnhrR1Yr0IqO6vdIIV7MHuTZkdBtaAbHU45uD0=s10000'}],
#    'overall_rating': 2.7,
#    'reviews': 970,
#    'ratings': [{'stars': 5, 'count': 273},
#     {'stars': 4, 'count': 107},
#     {'stars': 3, 'count': 95},
#     {'stars': 2, 'count': 75},
#     {'stars': 1, 'count': 420}],
#    'location_rating': 3.9,
#    'reviews_breakdown': [{'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 252,
#      'positive': 66,
#      'negative': 170,
#      'neutral': 16},
#     {'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 148,
#      'positive': 17,
#      'negative': 119,
#      'neutral': 12},
#     {'name': 'TV',
#      'description': 'Room entertainment',
#      'total_mentioned': 22,
#      'positive': 2,
#      'negative': 17,
#      'neutral': 3},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 264,
#      'positive': 142,
#      'negative': 103,
#      'neutral': 19},
#     {'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 291,
#      'positive': 110,
#      'negative': 155,
#      'neutral': 26},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 144,
#      'positive': 26,
#      'negative': 101,
#      'neutral': 17}],
#    'amenities': ['Free Wi-Fi', 'Restaurant'],
#    'property_token': 'ChcI3Z7o4Km47_0nGgsvZy8xdGZjaDF4aBAB',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChcI3Z7o4Km47_0nGgsvZy8xdGZjaDF4aBAB&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'ibis budget Paris Porte de Montmartre',
#    'description': 'Laid-back lodging offering simple rooms with complimentary Wi-Fi, plus a relaxed cafe.',
#    'link': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=2597&merchantid=seo-maps-FR-2597&sourceid=aw-cen&utm_medium=seo%20maps&utm_source=google%20Maps&utm_campaign=seo%20maps',
#    'gps_coordinates': {'latitude': 48.9012489, 'longitude': 2.3339241},
#    'check_in_time': '12:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€60',
#     'extracted_lowest': 60,
#     'before_taxes_fees': '€47',
#     'extracted_before_taxes_fees': 47},
#    'total_rate': {'lowest': '€120',
#     'extracted_lowest': 120,
#     'before_taxes_fees': '€94',
#     'extracted_before_taxes_fees': 94},
#    'nearby_places': [{'name': 'Porte de Clichy',
#      'transportations': [{'type': 'Taxi', 'duration': '7 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
# ...
#      'original_image': 'https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/4/0/60/316/312/Triple_room_O.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMs2Sh07ehtrzJ4zbcgfQ1muxLwTcjMOeBznPON=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMs2Sh07ehtrzJ4zbcgfQ1muxLwTcjMOeBznPON=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/aSU8la2zJr_a4KbCzkjW1urb_EmxkKtAktVlzZaq7ALQUbvUe1kZJHFYiJf2f2gPmSyLkfUCbdH8Ped7cr5_6uYbmPNHjc_MVamSegjdc7hAk6qlZ7IMHfw_rYcigaR4hMstNEtKe-g_TIBIWYNwGnl8pYQUTw=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://www.iceportal.com/data/2813-43786-f71916063_XXLejpg/France/PARIS-Bagnolet/Campanile-PARIS-EST-Porte-de-Bagnolet/Photo/Campanile-PARIS-EST-Porte-de-Bagnolet-PARIS-Bagnolet-Undefined-Campanile-Bagnolet.jpg'},
#     {'thumbnail': 'https://lh4.googleusercontent.com/proxy/r-vbeCqqm30QzEdQ2rHvAWaWMAF8ngJOpzX3dPg6uNG4kLl2_efX0-aSBlvgYiV_HMMJsD0LGz_9cVjoEuqCR5b90KK5MWceZ8PWPwr_-v5vnGZz_a3beOSpVqeYwsgXlY3KJj0N5lrcO3ZW29l8OOWTVLCNow=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/07/074702/074702a_hb_a_025.jpg'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/sQfe3GIIky-AYb73BHH7PJrIrlIDM1kDmbyYqqPBJxJFxwxELlOFN3p5dfr_ES-bPzVk5yCDQbGCmft94dqk7EvyUzaXV61_dBx95QFTXEr26l73HV4aLNMb87RZrhUCPFSOg3uU9tV06NFIK-YHJMIT-JHEmSQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/4/0/60/316/236/Lobby_O.jpg'},
#     {'thumbnail': 'https://lh6.googleusercontent.com/proxy/wJHHu5SeXKBv4ODyTJLHD8q9rPoLwiVSjO48PmKk-MBVrCdSSzDZiPgR1JFS9PFz0z7oCVSotSlrLw9FjwnaLfNZCwzQ7UpYlXSez9T98BJ--m_AqB7GO1iZK9vJ84NVR0emgYvvxFGDdDcbdefWKM5CdxWmQg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://www.iceportal.com/data/2813-43786-f1597206_XXLejpg/France/PARIS-Bagnolet/Campanile-PARIS-EST-Porte-de-Bagnolet/Photo/Campanile-PARIS-EST-Porte-de-Bagnolet-PARIS-Bagnolet-Undefined-Campanile-Bagnolet.jpg'},
#     {'thumbnail': 'https://lh4.googleusercontent.com/proxy/Jj__cYVClPIvfRazlsKuGPoimyERnMAxebu_yDg31iDqV6NBCg6KoD_Nhb88uze_IDoDghSr8lHpwq9VBpu8I5b_BiavMaRA0zUY7ljsRGECSRmpOrazYEBWiLClD94-xIyx5WJsdZ4Auv_40Ekb7oerqadn_pk=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://d2hyz2bfif3cr8.cloudfront.net/imageRepo/4/0/60/316/465/Meeting_room_O.jpg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/cqQxx6pjTBbhvdvlHT_r9vcIACKuoJ6L3qODpU8svUb_nLnVX8bYvUCKDxm5egczXi_L16NcgMV4KjgGLEc04KV_q5v2-CCZEDjYFJvPpyunYb6BqiyLZBqXs3A3sFxmgGnPRXikgzhW5EkPB6u0z67kqrx2UWQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/07/074702/074702a_hb_t_002.jpg'}],
#    'overall_rating': 3.3,
#    'reviews': 1241,
#    'ratings': [{'stars': 5, 'count': 332},
#     {'stars': 4, 'count': 311},
#     {'stars': 3, 'count': 219},
#     {'stars': 2, 'count': 137},
#     {'stars': 1, 'count': 242}],
#    'location_rating': 3.1,
#    'reviews_breakdown': [{'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 283,
#      'positive': 135,
#      'negative': 115,
#      'neutral': 33},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 213,
#      'positive': 108,
#      'negative': 86,
#      'neutral': 19},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 251,
#      'positive': 151,
#      'negative': 83,
#      'neutral': 17},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 223,
#      'positive': 144,
#      'negative': 37,
#      'neutral': 42},
#     {'name': 'Breakfast',
#      'description': 'Breakfast',
#      'total_mentioned': 112,
#      'positive': 56,
#      'negative': 45,
#      'neutral': 11},
#     {'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 112,
#      'positive': 19,
#      'negative': 80,
#      'neutral': 13}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Parking ($)',
#     'Pet-friendly',
#     'Bar',
#     'Restaurant',
#     'Room service',
#     'Airport shuttle',
#     'Accessible',
#     'Child-friendly',
#     'Smoke-free property'],
#    'property_token': 'ChkIv4Ga2IPAqcelARoML2cvMWhtMXdfMDNxEAE',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChkIv4Ga2IPAqcelARoML2cvMWhtMXdfMDNxEAE&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'ibis budget Saint-Maurice',
#    'description': 'Casual, modern rooms, some with bunk beds, in a modest budget hotel featuring complimentary Wi-Fi.',
#    'link': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=2712&merchantid=seo-maps-FR-2712&sourceid=aw-cen&utm_medium=seo%20maps&utm_source=google%20Maps&utm_campaign=seo%20maps',
#    'gps_coordinates': {'latitude': 48.815864100000006, 'longitude': 2.4593113},
#    'check_in_time': '12:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€61',
#     'extracted_lowest': 61,
#     'before_taxes_fees': '€51',
#     'extracted_before_taxes_fees': 51},
#    'total_rate': {'lowest': '€123',
#     'extracted_lowest': 123,
#     'before_taxes_fees': '€102',
#     'extracted_before_taxes_fees': 102},
#    'nearby_places': [{'name': 'Ecoles de Gravelle',
#      'transportations': [{'type': 'Walking', 'duration': '1 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '33 min'},
#       {'type': 'Public transport', 'duration': '1 hr 12 min'}]},
#     {'name': 'Chez Yong',
#      'transportations': [{'type': 'Walking', 'duration': '1 min'}]}],
#    'hotel_class': '2-star tourist hotel',
#    'extracted_hotel_class': 2,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMyMxfScIjSWiUUG3F-Sx6By8Xq96HUdTEBlajE=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMyMxfScIjSWiUUG3F-Sx6By8Xq96HUdTEBlajE=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNPCz2SXN70L7ESkvkcztdsWVpaPIbEeaaTq-Eq=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNPCz2SXN70L7ESkvkcztdsWVpaPIbEeaaTq-Eq=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPOYNEbMI8AefjsDNn3khX0dSloDly9qAW1RR-b=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPOYNEbMI8AefjsDNn3khX0dSloDly9qAW1RR-b=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNEs9dS32E1p90OtX0HUvUSuU9JBcAgxWc-AOR6=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNEs9dS32E1p90OtX0HUvUSuU9JBcAgxWc-AOR6=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMHmBM-8-vypmr4uVYyLWDhgrQpTGj-MHsqu1g3=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMHmBM-8-vypmr4uVYyLWDhgrQpTGj-MHsqu1g3=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipP5BDz0wT2hprg1-3FMw8yTXBEPwL4KfyWdzZEw=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipP5BDz0wT2hprg1-3FMw8yTXBEPwL4KfyWdzZEw=s10000'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/JgeAZ5l7kN4dG93qHXPaiwA_UX3ArQungQ_tkZwj-NgyGs99MIMsG2mzT0PHeCVVCUz8ttqAs-2MVbE2DL-xs4dGt4UxhPYapsU1WUcXuL8zNwUtgfRW4sQxDYI48zTRzWHo6tQBwTPBMGKnMRp9EWWt-oreYXY=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://photos.hotelbeds.com/giata/original/22/227828/227828a_hb_a_018.jpg'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/Ey9_-A_we95Wo16-TQMkMJuOA0nfoK87sWNEWEruvXB5fXeu6nGbprhY9qrHa2fxnC3POkvm5OFNQEP3k8zqMkBfO6l-00PyIBd2Ua2yK1ijqLdM4YHBQc0HX5nNkb1MeIRsfAwFoGVvNdh5Tg7ASExii3X4F4I=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://cdn.worldota.net/t/1024x768/content/ff/d0/ffd0e5ef10a42db42fb491cbe2dc636ac33d0d5a.jpeg'},
#     {'thumbnail': 'https://lh4.googleusercontent.com/proxy/Oqv5CZS2r8XqFS2KW2VYo8E40Yls1gDgKyC5Q0uhyDo8J9ulbUcMYfKHvx_la4X04l90hxLdc0m2R1nzq_mMErB3f6aVBEWGq95-5tssnlu6jGY-NRRqd08ga5nZaP1st-hhUs4_dBv7c0sDVXZEsiLq8Gi9eys=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0b/b2/32/57/la-reception.jpg?w=1900&h=1400&s=1'}],
#    'overall_rating': 3.6,
#    'reviews': 787,
#    'ratings': [{'stars': 5, 'count': 218},
#     {'stars': 4, 'count': 250},
#     {'stars': 3, 'count': 172},
#     {'stars': 2, 'count': 75},
#     {'stars': 1, 'count': 72}],
#    'location_rating': 3.2,
#    'reviews_breakdown': [{'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 150,
#      'positive': 90,
#      'negative': 38,
#      'neutral': 22},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 129,
#      'positive': 94,
#      'negative': 28,
#      'neutral': 7},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 130,
#      'positive': 95,
#      'negative': 26,
#      'neutral': 9},
#     {'name': 'Sleep',
#      'description': 'Sleep',
#      'total_mentioned': 87,
#      'positive': 30,
#      'negative': 47,
#      'neutral': 10},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 94,
#      'positive': 71,
#      'negative': 7,
#      'neutral': 16},
#     {'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 62,
#      'positive': 11,
#      'negative': 44,
#      'neutral': 7}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Air conditioning',
#     'Pet-friendly',
#     'Fitness centre',
#     'Accessible',
#     'Child-friendly',
#     'Smoke-free property'],
#    'eco_certified': True,
#    'property_token': 'ChcI7bvxx7PTtfk_GgsvZy8xeDVxczIzORAB',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChcI7bvxx7PTtfk_GgsvZy8xeDVxczIzORAB&q=Paris&sort_by=3'},
#   {'type': 'hotel',
#    'name': 'Hôtel Reseda Paris Porte de Bagnolet',
#    'description': 'Straightforward hotel offering unfussy rooms with free Wi-Fi, plus a meeting room.',
#    'link': 'http://www.hotel-reseda-paris.com/',
#    'gps_coordinates': {'latitude': 48.8662382, 'longitude': 2.4174499},
#    'check_in_time': '2:00\u202fPM',
#    'check_out_time': '12:00\u202fPM',
#    'rate_per_night': {'lowest': '€68',
#     'extracted_lowest': 68,
#     'before_taxes_fees': '€52',
#     'extracted_before_taxes_fees': 52},
#    'total_rate': {'lowest': '€135',
#     'extracted_lowest': 135,
#     'before_taxes_fees': '€104',
#     'extracted_before_taxes_fees': 104},
#    'nearby_places': [{'name': 'Cimetière du Père-Lachaise',
#      'transportations': [{'type': 'Public transport', 'duration': '9 min'},
#       {'type': 'Taxi', 'duration': '10 min'}]},
#     {'name': 'Paris Charles de Gaulle Airport',
#      'transportations': [{'type': 'Taxi', 'duration': '23 min'},
#       {'type': 'Public transport', 'duration': '56 min'}]},
#     {'name': 'Madame Gen restaurant',
#      'transportations': [{'type': 'Walking', 'duration': '4 min'}]}],
#    'hotel_class': '3-star tourist hotel',
#    'extracted_hotel_class': 3,
#    'images': [{'thumbnail': 'https://lh5.googleusercontent.com/proxy/GI00Uodm4xGgEcWMJDHrgL55nuty0dAjIBiYfSXkGB8AJNer7iX1EJHvtrGSNR5NlwJMCR1om1GJ6KaQAZ-BLzCzAkUS691FeHupi4DMnzPRaw7Nrxqj28x8e16H_AQo2ZzkKDtCM1hoPUthquOtHUERBoFBYg=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/http://media.staticontent.com/media/pictures/f8e4dc9f-7ad4-42f7-9882-298f90fe75d3=s10000'},
#     {'thumbnail': 'https://lh3.googleusercontent.com/proxy/sXEmbrVsixufPsgoAVtSfN8_bkOKAaRhrow_Rk9Q481C6GWSCrtg82uAT72BAtQ8TFj3vCvT3lFJtymsO-CnYv3PwoqvtrF4pGOynuDQ1o20oJjpaATBD1rHn3zKbBJGR-aRSpiLpZWl0MXFM1kyjXuZSLr0Zi4=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://cdn.worldota.net/t/1024x768/content/4d/e5/4de58967d81b0af9f2237f977f835cc990651b9f.jpeg'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipN2BNuQIk4_QpnFwGSN7bjWY2ZOeN6OaIsJohkK=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipN2BNuQIk4_QpnFwGSN7bjWY2ZOeN6OaIsJohkK=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPC82wLSPBbHUu8a_RovTBaeLuxvYpDyhYzYkvG=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPC82wLSPBbHUu8a_RovTBaeLuxvYpDyhYzYkvG=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/proxy/rOg5JfWx8d0g6qQPZuXWStjA-NxRNU6PJKBF-xpFfPWFA9MGh5vBaC3Lhw6ZMuVGl_S_g6uSKrElwVk1wYG4R89RZk7zEgI1tlgd452aXhVHMbqtKXHALEX5C-txx1gc3pdVtAgVYeXK3w_ix8s9BPfU2ZaoMw=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/db/d7/16/chambre-triple.jpg?w=1200&h=800&s=1'},
#     {'thumbnail': 'https://lh4.googleusercontent.com/proxy/RQHpd25lnjTfz7-YoG4frLgyCvfFr2RPOtLhfvPY4dyVPg0oSt8iedNfqZ64-YT6z_IvMh22jpUOBOwradTmY-jPVxP0A0mJ_ckQBF8XAwSSRKletYvSOlTrI5Ir6LlGePys83iLXj_yFmKTncjoUxWGWF-vEQ=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0d/05/1f/62/loby.jpg?w=1900&h=1400&s=1'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipMju_2dv4wNGYKK7mmYAsWYIedA27VHbDO-OmJF=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipMju_2dv4wNGYKK7mmYAsWYIedA27VHbDO-OmJF=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipPrcRAal-NHfBgLHAPnz7XrKoN6eMgnSLsTmQ1K=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipPrcRAal-NHfBgLHAPnz7XrKoN6eMgnSLsTmQ1K=s10000'},
#     {'thumbnail': 'https://lh5.googleusercontent.com/p/AF1QipNY_qTMB35zYN_V2zsOnZ3n9iKXVlEovwa093NU=s287-w287-h192-n-k-no-v1',
#      'original_image': 'https://lh5.googleusercontent.com/p/AF1QipNY_qTMB35zYN_V2zsOnZ3n9iKXVlEovwa093NU=s10000'}],
#    'overall_rating': 3.5,
#    'reviews': 2884,
#    'ratings': [{'stars': 5, 'count': 822},
#     {'stars': 4, 'count': 775},
#     {'stars': 3, 'count': 613},
#     {'stars': 2, 'count': 282},
#     {'stars': 1, 'count': 392}],
#    'location_rating': 3.1,
#    'reviews_breakdown': [{'name': 'Property',
#      'description': 'Property',
#      'total_mentioned': 595,
#      'positive': 260,
#      'negative': 249,
#      'neutral': 86},
#     {'name': 'Bathroom',
#      'description': 'Bathroom and toiletries',
#      'total_mentioned': 342,
#      'positive': 40,
#      'negative': 252,
#      'neutral': 50},
#     {'name': 'Cleanliness',
#      'description': 'Cleanliness',
#      'total_mentioned': 411,
#      'positive': 223,
#      'negative': 142,
#      'neutral': 46},
#     {'name': 'Breakfast',
#      'description': 'Breakfast',
#      'total_mentioned': 284,
#      'positive': 159,
#      'negative': 87,
#      'neutral': 38},
#     {'name': 'Location',
#      'description': 'Location',
#      'total_mentioned': 432,
#      'positive': 291,
#      'negative': 64,
#      'neutral': 77},
#     {'name': 'Service',
#      'description': 'Service',
#      'total_mentioned': 440,
#      'positive': 251,
#      'negative': 150,
#      'neutral': 39}],
#    'amenities': ['Breakfast ($)',
#     'Free Wi-Fi',
#     'Parking ($)',
#     'Air conditioning',
#     'Pet-friendly',
#     'Accessible',
#     'Child-friendly',
#     'Smoke-free property'],
#    'property_token': 'ChgI94f2xqyQjJqaARoLL2cvMXRjX3Z4aHMQAQ',
#    'serpapi_property_details_link': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&property_token=ChgI94f2xqyQjJqaARoLL2cvMXRjX3Z4aHMQAQ&q=Paris&sort_by=3'}],
#  'serpapi_pagination': {'current_from': 1,
#   'current_to': 18,
#   'next_page_token': 'CBI=',
#   'next': 'https://serpapi.com/search.json?adults=2&check_in_date=2024-10-31&check_out_date=2024-11-02&children=0&currency=EUR&engine=google_hotels&gl=us&hl=en&max_price=300&next_page_token=CBI%3D&q=Paris&sort_by=3'}}

# %%
hotel_queries[0]['properties'][0].keys()
# Out:
# dict_keys(['type', 'name', 'description', 'link', 'gps_coordinates', 'check_in_time', 'check_out_time', 'rate_per_night', 'total_rate', 'nearby_places', 'hotel_class', 'extracted_hotel_class', 'images', 'overall_rating', 'reviews', 'ratings', 'location_rating', 'reviews_breakdown', 'amenities', 'property_token', 'serpapi_property_details_link'])

# %%
### parse travel plan ---> cities soggiorno persone
### chiamata api -----> lista opzioni hotel [.....]
### lista opzioni, travel_plan -----> LLM ------> enriched travel plan (soggiorni)

# %% [markdown]
# ## 3c. From api results to enriched travel plan

# %%
GPTRAVEL_PROMPT_PARSER_TEMPLATE = """
You are an intelligent travel planner.

The user is interested to travel to {destination} between {departure_date} and {return_date}. 
In addition to that the user suggested this for his/her travel: "{travel_text}".

In the previous iterations, you did the following things:

- Created the following travel plan: {travel_plan}

- Checked on Google Flights the best outbound flight: {outbound_flights_options}
- Checked on Google Flights the best return flight: {return_flights_options}

- Checked on Google Hotels all possible accomodations for each travel day: {accomodation_options}

Given this in mind, we need to find the best combinations of flights and accomodation that could better fit user interests. 
You will give in output an enriched travel plan, where you will tell the activities to do and which flights to take and in which place to sleep and stay. 

Remember: 

- outbound flight details should coincide with the first date of travel .Remeber that outbound flight time should fit the time of activities. Re adapt the travel plan to fit the flight.
- return flight details should coincide with the first date of travel. Remeber that return flight time should fit the time of activities. Re adapt the travel plan to fit the flight.
- hotel details is a list of accomodations that should cover the whole travel dates. To find a good place, take into consideration what the user whant and his budget.
"""

# %%
class GpsCoordinates(BaseModel):
    latitude: float = Field(description="The latitude coordinate of the hotel.")
    longitude: float = Field(description="The longitude coordinate of the hotel.")

class Rate(BaseModel):
    lowest: str = Field(description="The lowest rate displayed as a string (including currency symbol).")
    extracted_lowest: int = Field(description="The extracted lowest rate as a numerical value.")
    before_taxes_fees: str = Field(description="The rate before taxes and fees, displayed as a string (including currency symbol).")
    extracted_before_taxes_fees: int = Field(description="The extracted rate before taxes and fees as a numerical value.")

class Transportation(BaseModel):
    type_: str = Field(description="Type of transportation (e.g., Taxi, Walking).")
    duration: str = Field(description="Estimated duration for the transportation option.")

class NearbyPlace(BaseModel):
    name: str = Field(description="Name of the nearby place.")
    transportations: List[Transportation] = Field(description="Available transportation options and their durations to the place.")

class Rating(BaseModel):
    stars: conint(ge=1, le=5) = Field(description="The number of stars given in the rating.")
    count: int = Field(description="The number of reviews that gave this star rating.")

class HotelDetails(BaseModel):
    type_: str = Field(description="The type of listing, in this case, 'hotel'.")
    name: str = Field(description="The name of the hotel.")
    description: str = Field(description="A brief description of the hotel.")
    gps_coordinates: GpsCoordinates = Field(description="The GPS coordinates (latitude and longitude) of the hotel.")
    check_in_time: str = Field(description="The check-in time at the hotel.")
    check_out_time: str = Field(description="The check-out time at the hotel.")
    rate_per_night: Rate = Field(description="Details about the rate per night, including lowest rates and rates before taxes and fees.")
    total_rate: Rate = Field(description="Total rate details for the stay, including lowest rates and rates before taxes and fees.")
    nearby_places: List[NearbyPlace] = Field(description="A list of places nearby the hotel, with available transportation options.")
    hotel_class: str = Field(description="The class of the hotel (e.g., 1-star tourist hotel).")
    overall_rating: float = Field(description="The overall rating of the hotel.")
    reviews: int = Field(description="The total number of reviews for the hotel.")
    ratings: List[Rating] = Field(description="A breakdown of ratings by star count.")
    location_rating: float = Field(description="The rating of the hotel's location.")
    amenities: List[str] = Field(description="A list of amenities provided by the hotel (e.g., Free Wi-Fi, Pet-friendly).")

# %%
class Airport(BaseModel):
    name: str = Field(description="The name of the airport.")
    airport_id: str = Field(description="The unique identifier (IATA code) of the airport.")
    time: str = Field(description="The scheduled time of departure or arrival.")

class Flight(BaseModel):
    departure_airport: Airport = Field(description="The departure airport details.")
    arrival_airport: Airport = Field(description="The arrival airport details.")
    duration: int = Field(description="Duration of the flight in minutes.")
    airline: str = Field(description="The airline operating the flight.")
    travel_class: str = Field(description="The travel class of the flight (e.g., Economy, Business).")
    flight_number: str = Field(description="The flight number assigned by the airline.")

class FlightDetails(BaseModel):
    flights: List[Flight] = Field(description="A list of flight segments included in this itinerary.")
    total_duration: int = Field(description="Total duration of the flight(s) in minutes.")
    price: int = Field(description="The price of the flight in the specified currency.")

class Activity(BaseModel):
    """Activity"""
    time: datetime.datetime = Field(description='Approximate time of the activicty. The format should be YYYY-MM-DD HH:MM:SS')
    place: str              = Field(description='Name of the place where is located the activicty')
    description: str        = Field(description='Description of the activicty')

class DayPlan(BaseModel):
    """Plan of a day in the travel plan"""
    date: datetime.date          = Field(description="Date of the plan.")
    activities: List[Activity]   = Field(description="List of activities to do in the day plan.")

class TravelPlan(BaseModel):
    """Travel plan"""
    day_plans: List[DayPlan] = Field(description="List of day plans activities.")


class EnrichedTravelPlan(BaseModel):
    activities_travel_plan: TravelPlan     = Field(description="Travel plan for the activities to do during the holiday.")
    outbound_flight_details: FlightDetails = Field(description="Detailed description of the outbound flight.") 
    return_flight_details: FlightDetails   = Field(description="Detailed description of the return flight.") 
    hotels_details: List[HotelDetails]     = Field(description="Detailed description of the accomodations for the travel.")

# %%
outbound_flight_options = json.dumps([
    FlightDetails(**eval(str(option).replace("'id': ", "'airport_id': "))).dict()
    for option in search_flight_result['outbound_input']['best_flights'] + search_flight_result['outbound_input']['other_flights']
])

return_flight_options = json.dumps([
    FlightDetails(**eval(str(option).replace("'id': ", "'airport_id': "))).dict()
    for option in search_flight_result['return_input']['best_flights'] + search_flight_result['return_input']['other_flights']
])

accomodation_options = json.dumps([
    [
        HotelDetails(**eval(str(hotel_queries[0]['properties'][0]).replace('type', 'type_'))).dict()
        for hotel_option in hotel_query['properties']
    ]
    for hotel_query in hotel_queries 
])

# %%
return_flight_options
# Out:
# '[{"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 06:05"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 07:35"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 4541"}], "total_duration": 90, "price": 36}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 09:05"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 10:35"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3806"}], "total_duration": 90, "price": 36}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 16:55"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 18:20"}, "duration": 85, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1730"}], "total_duration": 85, "price": 143}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 21:40"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 23:10"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3812"}], "total_duration": 90, "price": 74}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 13:00"}, "arrival_airport": {"name": "Josep Tarradellas Barcelona-El Prat Airport", "airport_id": "BCN", "time": "2024-11-02 14:50"}, "duration": 110, "airline": "Vueling", "travel_class": "Economy", "flight_number": "VY 8243"}, {"departure_airport": {"name": "Josep Tarradellas Barcelona-El Prat Airport", "airport_id": "BCN", "time": "2024-11-02 15:35"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 17:15"}, "duration": 100, "airline": "Vueling", "travel_class": "Economy", "flight_number": "VY 6334"}], "total_duration": 255, "price": 100}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 08:05"}, "arrival_airport": {"name": "Amsterdam Airport Schiphol", "airport_id": "AMS", "time": "2024-11-02 09:30"}, "duration": 85, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1340"}, {"departure_airport": {"name": "Amsterdam Airport Schiphol", "airport_id": "AMS", "time": "2024-11-02 14:35"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 16:10"}, "duration": 95, "airline": "KLM", "travel_class": "Economy", "flight_number": "KL 1621"}], "total_duration": 485, "price": 102}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 15:00"}, "arrival_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "time": "2024-11-02 16:15"}, "duration": 75, "airline": "SWISS", "travel_class": "Economy", "flight_number": "LX 639"}, {"departure_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "time": "2024-11-02 17:20"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 18:15"}, "duration": 55, "airline": "SWISS", "travel_class": "Economy", "flight_number": "LX 1622"}], "total_duration": 195, "price": 131}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 07:10"}, "arrival_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-11-02 08:40"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 4148"}], "total_duration": 90, "price": 143}, {"flights": [{"departure_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-02 09:05"} ...

# %%
user_input
# Out:
# {'destination': 'Paris',
#  'departure_date': '2024-10-31',
#  'return_date': '2024-11-02',
#  'travel_text': "I wanna visit Paris with my girlfriend in a romantic weekend. I'd love to impress her but at the same time I'd love to visit the best places of the city. I would like to sleep also in a good place, maximum 300 euros per night."}

# %%
llm_parser = ChatOpenAI(model="gpt-4o")

prompt_template_parse = PromptTemplate(
    input_variables=[
        "destination", "departure_date",
        "return_date", "travel_text", 
        "travel_plan", "outbound_flights_options",
        "return_flights_options", "accomodation_options"
    ],
    template=GPTRAVEL_PROMPT_PARSER_TEMPLATE
)

params_parse = user_input | {
    "travel_plan": travel_plan_output.json(),
    "outbound_flights_options": outbound_flight_options,
    "return_flights_options": outbound_flight_options,
    "accomodation_options": accomodation_options
}


params_parse
# Out:
# {'destination': 'Paris',
#  'departure_date': '2024-10-31',
#  'return_date': '2024-11-02',
#  'travel_text': "I wanna visit Paris with my girlfriend in a romantic weekend. I'd love to impress her but at the same time I'd love to visit the best places of the city. I would like to sleep also in a good place, maximum 300 euros per night.",
#  'travel_plan': '{"day_plans": [{"date": "2024-10-31", "activities": [{"time": "2024-10-31T10:00:00", "place": "Eiffel Tower", "description": "Start your romantic weekend with a visit to the iconic Eiffel Tower. Take an elevator ride to the top for a breathtaking view of Paris."}, {"time": "2024-10-31T12:00:00", "place": "Champs-\\u00c9lys\\u00e9es", "description": "Stroll down the famous avenue, stopping by luxury boutiques and cafes. Enjoy some shopping and people-watching."}, {"time": "2024-10-31T15:00:00", "place": "Louvre Museum", "description": "Visit the world\'s largest art museum and a historic monument in Paris. Don\'t miss the Mona Lisa and the Venus de Milo."}, {"time": "2024-10-31T18:00:00", "place": "Seine River", "description": "Take a romantic evening cruise on the Seine River. Enjoy the beautiful views of the city\'s landmarks illuminated at night."}]}, {"date": "2024-11-01", "activities": [{"time": "2024-11-01T10:00:00", "place": "Montmartre", "description": "Explore the charming district of Montmartre. Visit the Basilica of the Sacr\\u00e9-C\\u0153ur and enjoy the artistic atmosphere."}, {"time": "2024-11-01T12:00:00", "place": "Le Marais", "description": "Wander through the historic Le Marais district. Discover its narrow streets, trendy boutiques, and historic buildings."}, {"time": "2024-11-01T15:00:00", "place": "Notre-Dame Cathedral", "description": "Visit the stunning Notre-Dame Cathedral. Admire its Gothic architecture and explore its interior."}, {"time": "2024-11-01T18:00:00", "place": "Luxembourg Gardens", "description": "Take a romantic walk in the beautiful Luxembourg Gardens. Relax by the fountains and enjoy the serene environment."}]}, {"date": "2024-11-02", "activities": [{"time": "2024-11-02T10:00:00", "place": "Mus\\u00e9e d\'Orsay", "description": "Visit the Mus\\u00e9e d\'Orsay, known for its impressive collection of Impressionist and Post-Impressionist masterpieces."}, {"time": "2024-11-02T12:00:00", "place": "Saint-Germain-des-Pr\\u00e9s", "description": "Explore the historic Saint-Germain-des-Pr\\u00e9s neighborhood. Visit its famous cafes and bookstores."}, {"time": "2024-11-02T15:00:00", "place": "Palace of Versailles", "description": "Take a half-day trip to the Palace of Versailles. Explore the opulent palace and its stunning gardens."}, {"time": "2024-11-02T18:00:00", "place": "Montparnasse Tower", "description": "End your romantic weekend with a visit to the Montparnasse Tower. Enjoy a panoramic view of Paris at sunset."}]}]}',
#  'outbound_flights_options': '[{"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:45"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:15"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3809"}], "total_duration": 90, "price": 118}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 16:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:35"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1331"}], "total_duration": 90, "price": 181}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 12:35"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:05"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1131"}], "total_duration": 90, "price": 190}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 19:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 20:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3811"}], "total_duration": 95, "price": 114}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 06:25"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 08:00"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3805"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 13:15"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:45"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 4544"}], "total_duration": 90, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 18:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 19:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3813"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 08:25"}, "arrival_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-10-31 09:45"}, "duration": 80, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 6992"}, {"departure_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-11-01 16:00"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-01 17:00"}, "duration": 60, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 8019"}], "total_duration": 1955, "price": 140}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 11:50"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 13:20"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3807"}], "total_duration": 90, "price": 154}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:00"}, "arrival_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "time": "2024-10-31 16:00"}, "duration": 60, "airline": "SWISS", "travel_class": "Economy", "flight_number": "LX 1629"}, {"departure_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "ti ...
#  'return_flights_options': '[{"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:45"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:15"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3809"}], "total_duration": 90, "price": 118}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 16:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:35"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1331"}], "total_duration": 90, "price": 181}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 12:35"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:05"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1131"}], "total_duration": 90, "price": 190}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 19:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 20:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3811"}], "total_duration": 95, "price": 114}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 06:25"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 08:00"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3805"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 13:15"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:45"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 4544"}], "total_duration": 90, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 18:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 19:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3813"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 08:25"}, "arrival_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-10-31 09:45"}, "duration": 80, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 6992"}, {"departure_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-11-01 16:00"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-01 17:00"}, "duration": 60, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 8019"}], "total_duration": 1955, "price": 140}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 11:50"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 13:20"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3807"}], "total_duration": 90, "price": 154}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:00"}, "arrival_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "time": "2024-10-31 16:00"}, "duration": 60, "airline": "SWISS", "travel_class": "Economy", "flight_number": "LX 1629"}, {"departure_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "time ...
#  'accomodation_options': '[[{"type_": "hotel", "name": "hotelF1 Paris Porte de Montreuil", "description": "Modern lodging with free WiFi & basic rooms with shared bathrooms, plus in some cases, bunk beds.", "gps_coordinates": {"latitude": 48.8557601, "longitude": 2.4161588}, "check_in_time": "2:00\\u202fPM", "check_out_time": "12:00\\u202fPM", "rate_per_night": {"lowest": "\\u20ac41", "extracted_lowest": 41, "before_taxes_fees": "\\u20ac33", "extracted_before_taxes_fees": 33}, "total_rate": {"lowest": "\\u20ac82", "extracted_lowest": 82, "before_taxes_fees": "\\u20ac65", "extracted_before_taxes_fees": 65}, "nearby_places": [{"name": "Nation", "transportations": [{"type_": "Taxi", "duration": "9 min"}]}, {"name": "Paris Charles de Gaulle Airport", "transportations": [{"type_": "Taxi", "duration": "23 min"}, {"type_": "Public transport", "duration": "1 hr 3 min"}]}, {"name": "Adil\'s", "transportations": [{"type_": "Walking", "duration": "1 min"}]}], "hotel_class": "1-star tourist hotel", "overall_rating": 3.4, "reviews": 1999, "ratings": [{"stars": 5, "count": 608}, {"stars": 4, "count": 449}, {"stars": 3, "count": 357}, {"stars": 2, "count": 214}, {"stars": 1, "count": 371}], "location_rating": 3.4, "amenities": ["Breakfast ($)", "Free Wi-Fi", "Parking ($)", "Air conditioning", "Pet-friendly", "Accessible", "Child-friendly"]}, {"type_": "hotel", "name": "hotelF1 Paris Porte de Montreuil", "description": "Modern lodging with free WiFi & basic rooms with shared bathrooms, plus in some cases, bunk beds.", "gps_coordinates": {"latitude": 48.8557601, "longitude": 2.4161588}, "check_in_time": "2:00\\u202fPM", "check_out_time": "12:00\\u202fPM", "rate_per_night": {"lowest": "\\u20ac41", "extracted_lowest": 41, "before_taxes_fees": "\\u20ac33", "extracted_before_taxes_fees": 33}, "total_rate": {"lowest": "\\u20ac82", "extracted_lowest": 82, "before_taxes_fees": "\\u20ac65", "extracted_before_taxes_fees": 65}, "nearby_places": [{"name": "Nation", "transportations": [{"type_": "Taxi", "duration": "9 min"}]}, {"name": "Paris Charles de Gaulle Airport", "transportations": [{"type_": "Taxi", "duration": "23 min"}, {"type_": "Public transport", "duration": "1 hr 3 min"}]}, {"name": "Adil\'s", "transportations": [{"type_": "Walking", "duration": "1 min"}]}], "hotel_class": "1-star tourist hotel", "overall_rating": 3.4, "reviews": 1999, "ratings": [{"stars": 5, "count": 608}, {"stars": 4, "count": 449}, {"stars": 3, "count": 357}, {"stars": 2, "count": 214}, {"stars": 1, "count": 371}], "location_rating": 3.4, "amenities": ["Breakfast ($)", "Free Wi-Fi", "Parking ($)", "Air conditioning", "Pet-friendly", "Accessible", "Child-friendly"]}, {"type_": "hotel", "name": "hotelF1 Paris Porte de Montreuil", "description": "Modern lodging with free WiFi & basic rooms with shared bathrooms, plus in some cases, bunk beds.", "gps_coordinates": {"latitude": 48.8557601, "longitude": 2.4161588}, "check_in_time": "2:00\\u202fPM", "check_out_time": "12:00\\u202fPM", "rate_per_night": {"lowest": "\\u20ac41", "extracted_lowest": 41, "before_taxes_fees": "\\u20ac33", "extracted_before_taxes_fees": 33}, "total_rate": {"lowest": "\\u20ac82", "extracted_lowest": 82, "before_taxes_fees": "\\u20ac65", "extracted_before_taxes_fees": 65}, "nearby_places": [{"name": "Nation", "transportations": [{"type_": "Taxi", "duration": "9 min"}]}, {"name": "Paris Charles de Gaulle Airport", "transportations": [{"type_": "Taxi", "duration": "23 min"}, {"type_": "Public transport", "duration": "1 hr 3 min"}]}, {"name": "Adil\'s", "transportations": [{"type_": "Walking", "duration": "1 min"}]}], "hotel_class": "1-star tourist hotel", "overall_rating": 3.4, "reviews": 1999, "ratings": [{"stars": 5, "count": 608}, {"stars": 4, "count": 449}, {"stars": 3, "count": 357}, {"stars": 2, "count": 214}, {"stars": 1, "count": 371}], "location_rating": 3.4, "amenities": ["Breakfast ($)", "Free Wi-Fi", "Parking ($)", "Air conditioning", "Pet-friendly", "Accessible", "Child-friendly"]}, {"type_": ...

# %%
structured_llm_parser = llm_parser.with_structured_output(EnrichedTravelPlan)

# %%
print(prompt_template_parse.format(**params_parse))
# Out:
# You are an intelligent travel planner.
#
# The user is interested to travel to Paris between 2024-10-31 and 2024-11-02.
# In addition to that the user suggested this for his/her travel: "I wanna visit Paris with my girlfriend in a romantic weekend. I'd love to impress her but at the same time I'd love to visit the best places of the city. I would like to sleep also in a good place, maximum 300 euros per night.".
#
# In the previous iterations, you did the following things:
#
# - Created the following travel plan: {"day_plans": [{"date": "2024-10-31", "activities": [{"time": "2024-10-31T10:00:00", "place": "Eiffel Tower", "description": "Start your romantic weekend with a visit to the iconic Eiffel Tower. Take an elevator ride to the top for a breathtaking view of Paris."}, {"time": "2024-10-31T12:00:00", "place": "Champs-\u00c9lys\u00e9es", "description": "Stroll down the famous avenue, stopping by luxury boutiques and cafes. Enjoy some shopping and people-watching."}, {"time": "2024-10-31T15:00:00", "place": "Louvre Museum", "description": "Visit the world's largest art museum and a historic monument in Paris. Don't miss the Mona Lisa and the Venus de Milo."}, {"time": "2024-10-31T18:00:00", "place": "Seine River", "description": "Take a romantic evening cruise on the Seine River. Enjoy the beautiful views of the city's landmarks illuminated at night."}]}, {"date": "2024-11-01", "activities": [{"time": "2024-11-01T10:00:00", "place": "Montmartre", "description": "Explore the charming district of Montmartre. Visit the Basilica of the Sacr\u00e9-C\u0153ur and enjoy the artistic atmosphere."}, {"time": "2024-11-01T12:00:00", "place": "Le Marais", "description": "Wander through the historic Le Marais district. Discover its narrow streets, trendy boutiques, and historic buildings."}, {"time": "2024-11-01T15:00:00", "place": "Notre-Dame Cathedral", "description": "Visit the stunning Notre-Dame Cathedral. Admire its Gothic architecture and explore its interior."}, {"time": "2024-11-01T18:00:00", "place": "Luxembourg Gardens", "description": "Take a romantic walk in the beautiful Luxembourg Gardens. Relax by the fountains and enjoy the serene environment."}]}, {"date": "2024-11-02", "activities": [{"time": "2024-11-02T10:00:00", "place": "Mus\u00e9e d'Orsay", "description": "Visit the Mus\u00e9e d'Orsay, known for its impressive collection of Impressionist and Post-Impressionist masterpieces."}, {"time": "2024-11-02T12:00:00", "place": "Saint-Germain-des-Pr\u00e9s", "description": "Explore the historic Saint-Germain-des-Pr\u00e9s neighborhood. Visit its famous cafes and bookstores."}, {"time": "2024-11-02T15:00:00", "place": "Palace of Versailles", "description": "Take a half-day trip to the Palace of Versailles. Explore the opulent palace and its stunning gardens."}, {"time": "2024-11-02T18:00:00", "place": "Montparnasse Tower", "description": "End your romantic weekend with a visit to the Montparnasse Tower. Enjoy a panoramic view of Paris at sunset."}]}]}
#
# - Checked on Google Flights the best outbound flight: [{"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:45"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:15"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3809"}], "total_duration": 90, "price": 118}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 16:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:35"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1331"}], "total_duration": 90, "price": 181}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 12:35"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:05"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1131"}], "total_duration": 90, "price": 190}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 19:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 20:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3811"}], "total_duration": 95, "price": 114}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 06:25"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 08:00"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3805"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 13:15"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:45"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 4544"}], "total_duration": 90, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 18:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 19:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3813"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 08:25"}, "arrival_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-10-31 09:45"}, "duration": 80, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 6992"}, {"departure_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-11-01 16:00"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-01 17:00"}, "duration": 60, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 8019"}], "total_duration": 1955, "price": 140}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 11:50"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 13:20"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3807"}], "total_duration": 90, "price": 154}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:00"}, "arrival_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "time": "2024-10-31 16:00"}, "duration": 60, "airline": "SWISS", "travel_class": "Economy", "flight_number": "LX 1629"}, {"departure_airport": {"name": "Zurich Airport",  ...
# - Checked on Google Flights the best return flight: [{"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:45"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:15"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3809"}], "total_duration": 90, "price": 118}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 16:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 17:35"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1331"}], "total_duration": 90, "price": 181}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 12:35"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:05"}, "duration": 90, "airline": "Air France", "travel_class": "Economy", "flight_number": "AF 1131"}], "total_duration": 90, "price": 190}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 19:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 20:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3811"}], "total_duration": 95, "price": 114}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 06:25"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 08:00"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3805"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 13:15"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 14:45"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 4544"}], "total_duration": 90, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 18:05"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 19:40"}, "duration": 95, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3813"}], "total_duration": 95, "price": 132}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 08:25"}, "arrival_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-10-31 09:45"}, "duration": 80, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 6992"}, {"departure_airport": {"name": "Luxembourg Airport", "airport_id": "LUX", "time": "2024-11-01 16:00"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-11-01 17:00"}, "duration": 60, "airline": "Luxair", "travel_class": "Economy", "flight_number": "LG 8019"}], "total_duration": 1955, "price": 140}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 11:50"}, "arrival_airport": {"name": "Paris Charles de Gaulle Airport", "airport_id": "CDG", "time": "2024-10-31 13:20"}, "duration": 90, "airline": "easyJet", "travel_class": "Economy", "flight_number": "U2 3807"}], "total_duration": 90, "price": 154}, {"flights": [{"departure_airport": {"name": "Milan Malpensa Airport", "airport_id": "MXP", "time": "2024-10-31 15:00"}, "arrival_airport": {"name": "Zurich Airport", "airport_id": "ZRH", "time": "2024-10-31 16:00"}, "duration": 60, "airline": "SWISS", "travel_class": "Economy", "flight_number": "LX 1629"}, {"departure_airport": {"name": "Zurich Airport", "a ...
#
# - Checked on Google Hotels all possible accomodations for each travel day: [[{"type_": "hotel", "name": "hotelF1 Paris Porte de Montreuil", "description": "Modern lodging with free WiFi & basic rooms with shared bathrooms, plus in some cases, bunk beds.", "gps_coordinates": {"latitude": 48.8557601, "longitude": 2.4161588}, "check_in_time": "2:00\u202fPM", "check_out_time": "12:00\u202fPM", "rate_per_night": {"lowest": "\u20ac41", "extracted_lowest": 41, "before_taxes_fees": "\u20ac33", "extracted_before_taxes_fees": 33}, "total_rate": {"lowest": "\u20ac82", "extracted_lowest": 82, "before_taxes_fees": "\u20ac65", "extracted_before_taxes_fees": 65}, "nearby_places": [{"name": "Nation", "transportations": [{"type_": "Taxi", "duration": "9 min"}]}, {"name": "Paris Charles de Gaulle Airport", "transportations": [{"type_": "Taxi", "duration": "23 min"}, {"type_": "Public transport", "duration": "1 hr 3 min"}]}, {"name": "Adil's", "transportations": [{"type_": "Walking", "duration": "1 min"}]}], "hotel_class": "1-star tourist hotel", "overall_rating": 3.4, "reviews": 1999, "ratings": [{"stars": 5, "count": 608}, {"stars": 4, "count": 449}, {"stars": 3, "count": 357}, {"stars": 2, "count": 214}, {"stars": 1, "count": 371}], "location_rating": 3.4, "amenities": ["Breakfast ($)", "Free Wi-Fi", "Parking ($)", "Air conditioning", "Pet-friendly", "Accessible", "Child-friendly"]}, {"type_": "hotel", "name": "hotelF1 Paris Porte de Montreuil", "description": "Modern lodging with free WiFi & basic rooms with shared bathrooms, plus in some cases, bunk beds.", "gps_coordinates": {"latitude": 48.8557601, "longitude": 2.4161588}, "check_in_time": "2:00\u202fPM", "check_out_time": "12:00\u202fPM", "rate_per_night": {"lowest": "\u20ac41", "extracted_lowest": 41, "before_taxes_fees": "\u20ac33", "extracted_before_taxes_fees": 33}, "total_rate": {"lowest": "\u20ac82", "extracted_lowest": 82, "before_taxes_fees": "\u20ac65", "extracted_before_taxes_fees": 65}, "nearby_places": [{"name": "Nation", "transportations": [{"type_": "Taxi", "duration": "9 min"}]}, {"name": "Paris Charles de Gaulle Airport", "transportations": [{"type_": "Taxi", "duration": "23 min"}, {"type_": "Public transport", "duration": "1 hr 3 min"}]}, {"name": "Adil's", "transportations": [{"type_": "Walking", "duration": "1 min"}]}], "hotel_class": "1-star tourist hotel", "overall_rating": 3.4, "reviews": 1999, "ratings": [{"stars": 5, "count": 608}, {"stars": 4, "count": 449}, {"stars": 3, "count": 357}, {"stars": 2, "count": 214}, {"stars": 1, "count": 371}], "location_rating": 3.4, "amenities": ["Breakfast ($)", "Free Wi-Fi", "Parking ($)", "Air conditioning", "Pet-friendly", "Accessible", "Child-friendly"]}, {"type_": "hotel", "name": "hotelF1 Paris Porte de Montreuil", "description": "Modern lodging with free WiFi & basic rooms with shared bathrooms, plus in some cases, bunk beds.", "gps_coordinates": {"latitude": 48.8557601, "longitude": 2.4161588}, "check_in_time": "2:00\u202fPM", "check_out_time": "12:00\u202fPM", "rate_per_night": {"lowest": "\u20ac41", "extracted_lowest": 41, "before_taxes_fees": "\u20ac33", "extracted_before_taxes_fees": 33}, "total_rate": {"lowest": "\u20ac82", "extracted_lowest": 82, "before_taxes_fees": "\u20ac65", "extracted_before_taxes_fees": 65}, "nearby_places": [{"name": "Nation", "transportations": [{"type_": "Taxi", "duration": "9 min"}]}, {"name": "Paris Charles de Gaulle Airport", "transportations": [{"type_": "Taxi", "duration": "23 min"}, {"type_": "Public transport", "duration": "1 hr 3 min"}]}, {"name": "Adil's", "transportations": [{"type_": "Walking", "duration": "1 min"}]}], "hotel_class": "1-star tourist hotel", "overall_rating": 3.4, "reviews": 1999, "ratings": [{"stars": 5, "count": 608}, {"stars": 4, "count": 449}, {"stars": 3, "count": 357}, {"stars": 2, "count": 214}, {"stars": 1, "count": 371}], "location_rating": 3.4, "amenities": ["Breakfast ($)", "Free Wi-Fi", "Parking ($)", "Air conditioning", "Pet-friendly", "Accessible", " ...
#
# Given this in mind, we need to find the best combinations of flights and accomodation that could better fit user interests.
# You will give in output an enriched travel plan, where you will tell the activities to do and which flights to take and in which place to sleep and stay.
#
# Remember:
#
# - outbound flight details should coincide with the first date of travel .Remeber that outbound flight time should fit the time of activities. Re adapt the travel plan to fit the flight.
# - return flight details should coincide with the first date of travel. Remeber that return flight time should fit the time of activities. Re adapt the travel plan to fit the flight.
# - hotel details is a list of accomodations that should cover the whole travel dates. To find a good place, take into consideration what the user whant and his budget.

# %%
enriched_travel_plan_output = structured_llm_parser.invoke(
    prompt_template_parse.format(**params_parse)
)

# %%
print(enriched_travel_plan_output.json())
# Out:
# {"activities_travel_plan":{"day_plans":[{"date":"2024-10-31","activities":[{"time":"2024-10-31T18:00:00","place":"Eiffel Tower","description":"Start your romantic weekend with a visit to the iconic Eiffel Tower. Take an elevator ride to the top for a breathtaking view of Paris."},{"time":"2024-10-31T20:00:00","place":"Champs-Élysées","description":"Stroll down the famous avenue, stopping by luxury boutiques and cafes. Enjoy some shopping and people-watching."}]},{"date":"2024-11-01","activities":[{"time":"2024-11-01T10:00:00","place":"Louvre Museum","description":"Visit the world's largest art museum and a historic monument in Paris. Don't miss the Mona Lisa and the Venus de Milo."},{"time":"2024-11-01T12:00:00","place":"Seine River","description":"Take a romantic evening cruise on the Seine River. Enjoy the beautiful views of the city's landmarks illuminated at night."}]},{"date":"2024-11-02","activities":[{"time":"2024-11-02T10:00:00","place":"Montmartre","description":"Explore the charming district of Montmartre. Visit the Basilica of the Sacré-Cœur and enjoy the artistic atmosphere."},{"time":"2024-11-02T12:00:00","place":"Le Marais","description":"Wander through the historic Le Marais district. Discover its narrow streets, trendy boutiques, and historic buildings."},{"time":"2024-11-02T15:00:00","place":"Notre-Dame Cathedral","description":"Visit the stunning Notre-Dame Cathedral. Admire its Gothic architecture and explore its interior."}]}]},"outbound_flight_details":{"flights":[{"departure_airport":{"name":"Milan Malpensa Airport","airport_id":"MXP","time":"2024-10-31 15:45"},"arrival_airport":{"name":"Paris Charles de Gaulle Airport","airport_id":"CDG","time":"2024-10-31 17:15"},"duration":90,"airline":"easyJet","travel_class":"Economy","flight_number":"U2 3809"}],"total_duration":90,"price":118},"return_flight_details":{"flights":[{"departure_airport":{"name":"Paris Charles de Gaulle Airport","airport_id":"CDG","time":"2024-11-02 20:40"},"arrival_airport":{"name":"Milan Malpensa Airport","airport_id":"MXP","time":"2024-11-02 22:10"},"duration":90,"airline":"easyJet","travel_class":"Economy","flight_number":"U2 3811"}],"total_duration":90,"price":114},"hotels_details":[{"type_":"hotel","name":"Hotel de Fleurie","description":"Charming hotel in the heart of Saint-Germain-des-Prés, offering elegant rooms with free Wi-Fi and a romantic atmosphere.","gps_coordinates":{"latitude":48.852839,"longitude":2.337948},"check_in_time":"2:00 PM","check_out_time":"12:00 PM","rate_per_night":{"lowest":"€250","extracted_lowest":250,"before_taxes_fees":"€220","extracted_before_taxes_fees":220},"total_rate":{"lowest":"€500","extracted_lowest":500,"before_taxes_fees":"€440","extracted_before_taxes_fees":440},"nearby_places":[{"name":"Luxembourg Gardens","transportations":[{"type_":"Walking","duration":"5 min"}]},{"name":"Notre-Dame Cathedral","transportations":[{"type_":"Walking","duration":"15 min"}]}],"hotel_class":"4-star hotel","overall_rating":4.5,"reviews":1200,"ratings":[{"stars":5,"count":800},{"stars":4,"count":300},{"stars":3,"count":70},{"stars":2,"count":20},{"stars":1,"count":10}],"location_rating":4.8,"amenities":["Free Wi-Fi","Breakfast included","Air conditioning","24-hour front desk","Concierge service","Bar/lounge","Room service"]}]}
